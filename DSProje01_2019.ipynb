# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

# %%
df0 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190504.txt')
df0 = pd.DataFrame(df0)

# %%
df1 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190511.txt')
df1 = pd.DataFrame(df1)

# %%
df2 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190518.txt')
df2 = pd.DataFrame(df2)

# %%
df3 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190525.txt')
df3 = pd.DataFrame(df3)

# %%
df4 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190601.txt')
df4 = pd.DataFrame(df4)

# %%
df5 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190608.txt')
df5 = pd.DataFrame(df5)

# %%
df6 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190615.txt')
df6 = pd.DataFrame(df6)

# %%
df7 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190622.txt')
df7 = pd.DataFrame(df7)

# %%
df8 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190629.txt')
df8 = pd.DataFrame(df8)

# %%
df9 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190706.txt')
df9 = pd.DataFrame(df9)

# %%
df10 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190713.txt')
df10 = pd.DataFrame(df10)

# %%
df11 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190720.txt')
df11 = pd.DataFrame(df11)

# %%
df12 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190727.txt')
df12 = pd.DataFrame(df12)

# %%
df13 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190803.txt')
df13 = pd.DataFrame(df13)

# %%
df14 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190810.txt')
df14 = pd.DataFrame(df14)

# %%
df15 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190817.txt')
df15 = pd.DataFrame(df15)

# %%
df16 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190824.txt')
df16 = pd.DataFrame(df16)

# %%
df17 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190831.txt')
df17 = pd.DataFrame(df17)

# %%
df = pd.concat([df0, df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17], ignore_index = True)

# %%
df.info() ####11 kolonumuz var
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3716409 entries, 0 to 3716408
# Data columns (total 11 columns):
#  #   Column                                                                Dtype
# ---  ------                                                                -----
#  0   C/A                                                                   object
#  1   UNIT                                                                  object
#  2   SCP                                                                   object
#  3   STATION                                                               object
#  4   LINENAME                                                              object
#  5   DIVISION                                                              object
#  6   DATE                                                                  object
#  7   TIME                                                                  object
#  8   DESC                                                                  object
#  9   ENTRIES                                                               int64
#  10  EXITS                                                                 int64
# dtypes: int64(2), object(9)
# memory usage: 311.9+ MB

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7035249
# 1  REGULAR  7035269
# 2  REGULAR  7035292
# 3  REGULAR  7035392
# 4  REGULAR  7035651
#
#    EXITS
# 0                                            2384833
# 1                                            2384840
# 2                                            2384875
# 3                                            2384951
# 4                                            2385020

# %%
df.tail()
# Out:
#            C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 3716404  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/30/2019
# 3716405  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/30/2019
# 3716406  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/30/2019
# 3716407  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/30/2019
# 3716408  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/30/2019
#
#              TIME     DESC  ENTRIES  \
# 3716404  05:00:00  REGULAR     5554
# 3716405  09:00:00  REGULAR     5554
# 3716406  13:00:00  REGULAR     5554
# 3716407  17:00:00  REGULAR     5554
# 3716408  21:00:00  REGULAR     5554
#
#          EXITS
# 3716404                                                389
# 3716405                                                389
# 3716406                                                389
# 3716407                                                389
# 3716408                                                389

# %%
print(df.isnull().sum()) ###null deÄŸerleri kontrol ediyoruz
# Out:
# C/A                                                                     0
# UNIT                                                                    0
# SCP                                                                     0
# STATION                                                                 0
# LINENAME                                                                0
# DIVISION                                                                0
# DATE                                                                    0
# TIME                                                                    0
# DESC                                                                    0
# ENTRIES                                                                 0
# EXITS                                                                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
df.columns=df.columns.str.strip()

# %%
df['TIMESTAMP'] = pd.to_datetime(df['DATE'] + ' ' + df['TIME'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3716409 entries, 0 to 3716408
# Data columns (total 12 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   C/A        object
#  1   UNIT       object
#  2   SCP        object
#  3   STATION    object
#  4   LINENAME   object
#  5   DIVISION   object
#  6   DATE       object
#  7   TIME       object
#  8   DESC       object
#  9   ENTRIES    int64
#  10  EXITS      int64
#  11  TIMESTAMP  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(9)
# memory usage: 340.2+ MB

# %%
df['WEEKDAYS'] = pd.to_datetime(df['DATE']).dt.day_name()
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  16:00:00
#
#       DESC  ENTRIES    EXITS           TIMESTAMP  WEEKDAYS
# 0  REGULAR  7035249  2384833 2019-04-27 00:00:00  Saturday
# 1  REGULAR  7035269  2384840 2019-04-27 04:00:00  Saturday
# 2  REGULAR  7035292  2384875 2019-04-27 08:00:00  Saturday
# 3  REGULAR  7035392  2384951 2019-04-27 12:00:00  Saturday
# 4  REGULAR  7035651  2385020 2019-04-27 16:00:00  Saturday

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3716409 entries, 0 to 3716408
# Data columns (total 13 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   C/A        object
#  1   UNIT       object
#  2   SCP        object
#  3   STATION    object
#  4   LINENAME   object
#  5   DIVISION   object
#  6   DATE       object
#  7   TIME       object
#  8   DESC       object
#  9   ENTRIES    int64
#  10  EXITS      int64
#  11  TIMESTAMP  datetime64[ns]
#  12  WEEKDAYS   object
# dtypes: datetime64[ns](1), int64(2), object(10)
# memory usage: 368.6+ MB

# %%
df["TURNSTILE"] = df["C/A"]+"-"+df["UNIT"]+"-"+df["SCP"]

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS', 'TIMESTAMP', 'WEEKDAYS', 'TURNSTILE'],
#       dtype='object')

# %%
df.head(5)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  16:00:00
#
#       DESC  ENTRIES    EXITS           TIMESTAMP  WEEKDAYS           TURNSTILE
# 0  REGULAR  7035249  2384833 2019-04-27 00:00:00  Saturday  A002-R051-02-00-00
# 1  REGULAR  7035269  2384840 2019-04-27 04:00:00  Saturday  A002-R051-02-00-00
# 2  REGULAR  7035292  2384875 2019-04-27 08:00:00  Saturday  A002-R051-02-00-00
# 3  REGULAR  7035392  2384951 2019-04-27 12:00:00  Saturday  A002-R051-02-00-00
# 4  REGULAR  7035651  2385020 2019-04-27 16:00:00  Saturday  A002-R051-02-00-00

# %%
df.shape
# Out:
# (3716409, 14)

# %% [markdown]
# #Duplicate var ise sil

# %%
df.drop_duplicates(subset=None, keep="first", inplace=True)

# %%
df.shape
# Out:
# (3716409, 14)

# %%
df.describe()
# Out:
#             ENTRIES         EXITS
# count  3.716409e+06  3.716409e+06
# mean   4.202627e+07  3.445479e+07
# std    2.141353e+08  1.971565e+08
# min    0.000000e+00  0.000000e+00
# 25%    3.012690e+05  1.229840e+05
# 50%    2.129609e+06  1.216656e+06
# 75%    6.712024e+06  4.591477e+06
# max    2.129343e+09  2.124127e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3716409 entries, 0 to 3716408
# Data columns (total 14 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   C/A        object
#  1   UNIT       object
#  2   SCP        object
#  3   STATION    object
#  4   LINENAME   object
#  5   DIVISION   object
#  6   DATE       object
#  7   TIME       object
#  8   DESC       object
#  9   ENTRIES    int64
#  10  EXITS      int64
#  11  TIMESTAMP  datetime64[ns]
#  12  WEEKDAYS   object
#  13  TURNSTILE  object
# dtypes: datetime64[ns](1), int64(2), object(11)
# memory usage: 425.3+ MB

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  16:00:00
#
#       DESC  ENTRIES    EXITS           TIMESTAMP  WEEKDAYS           TURNSTILE
# 0  REGULAR  7035249  2384833 2019-04-27 00:00:00  Saturday  A002-R051-02-00-00
# 1  REGULAR  7035269  2384840 2019-04-27 04:00:00  Saturday  A002-R051-02-00-00
# 2  REGULAR  7035292  2384875 2019-04-27 08:00:00  Saturday  A002-R051-02-00-00
# 3  REGULAR  7035392  2384951 2019-04-27 12:00:00  Saturday  A002-R051-02-00-00
# 4  REGULAR  7035651  2385020 2019-04-27 16:00:00  Saturday  A002-R051-02-00-00

# %%
df = df[["STATION","TURNSTILE","DATE","TIME", "TIMESTAMP","ENTRIES","EXITS", "WEEKDAYS"]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3716409 entries, 0 to 3716408
# Data columns (total 8 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   STATION    object
#  1   TURNSTILE  object
#  2   DATE       object
#  3   TIME       object
#  4   TIMESTAMP  datetime64[ns]
#  5   ENTRIES    int64
#  6   EXITS      int64
#  7   WEEKDAYS   object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 255.2+ MB

# %%
print("Maximum date: ")
print(df["TIMESTAMP"].max())
print()
print("Minimum date: ")
print(df["TIMESTAMP"].min())
# Out:
# Maximum date:
# 2019-08-30 23:59:40
#
# Minimum date:
# 2019-04-27 00:00:00

# %%
len(df["STATION"].unique())
# Out:
# 378

# %%
len(df["TURNSTILE"].unique())
# Out:
# 4961

# %%
print("Row count based on stations (First 10 rows)")
print(df["STATION"].value_counts().sort_values(ascending=False).head(10))
# Out:
# Row count based on stations (First 10 rows)
# 34 ST-PENN STA     78315
# FULTON ST          75113
# 23 ST              55166
# GRD CNTRL-42 ST    52769
# 86 ST              47581
# CANAL ST           44251
# 34 ST-HERALD SQ    41704
# CHAMBERS ST        41500
# TIMES SQ-42 ST     39790
# 59 ST              39566
# Name: STATION, dtype: int64

# %%
df['NET_ENTRIES'] = df.ENTRIES.shift(-1) - df.ENTRIES
df['NET_EXITS'] = df.EXITS.shift(-1) - df.EXITS

# %%
df.head(50)
# Out:
#    STATION           TURNSTILE        DATE      TIME           TIMESTAMP  \
# 0    59 ST  A002-R051-02-00-00  04/27/2019  00:00:00 2019-04-27 00:00:00
# 1    59 ST  A002-R051-02-00-00  04/27/2019  04:00:00 2019-04-27 04:00:00
# 2    59 ST  A002-R051-02-00-00  04/27/2019  08:00:00 2019-04-27 08:00:00
# 3    59 ST  A002-R051-02-00-00  04/27/2019  12:00:00 2019-04-27 12:00:00
# 4    59 ST  A002-R051-02-00-00  04/27/2019  16:00:00 2019-04-27 16:00:00
# 5    59 ST  A002-R051-02-00-00  04/27/2019  20:00:00 2019-04-27 20:00:00
# 6    59 ST  A002-R051-02-00-00  04/28/2019  00:00:00 2019-04-28 00:00:00
# 7    59 ST  A002-R051-02-00-00  04/28/2019  04:00:00 2019-04-28 04:00:00
# 41  7043049  2387579     Friday        354.0       52.0
# 42  7043403  2387631     Friday        803.0       43.0
# 43  7044206  2387674     Friday    -775942.0  -981915.0
# 44  6268264  1405759   Saturday         11.0        3.0
# 45  6268275  1405762   Saturday         12.0       13.0
# 46  6268287  1405775   Saturday         86.0       40.0
# 47  6268373  1405815   Saturday        222.0       52.0
# 48  6268595  1405867   Saturday        255.0       27.0
# 49  6268850  1405894   Saturday        148.0       11.0

# %% [markdown]
# #Veriyi anlayabilmek iÃ§in tanÄ±mlayÄ±cÄ± istatistiklerine bakalÄ±m

# %%
print("Descriptive Statistics for NET_ENTRIES column:") 
print(df["NET_ENTRIES"].describe())
print("Descriptive Statistics for NET_EXITS column:")
print(df["NET_EXITS"].describe())
# Out:
# Descriptive Statistics for NET_ENTRIES column:
# count    3.716408e+06
# mean    -1.891529e+00
# std      4.506490e+07
# min     -2.116019e+09
# 25%      8.000000e+00
# 50%      6.900000e+01
# 75%      2.320000e+02
# max      2.121328e+09
# Name: NET_ENTRIES, dtype: float64
# Descriptive Statistics for NET_EXITS column:
# count    3.716408e+06
# mean    -6.415991e-01
# std      4.131917e+07
# min     -2.111175e+09
# 25%      7.000000e+00
# 50%      5.100000e+01
# 75%      1.650000e+02
# max      2.118904e+09
# Name: NET_EXITS, dtype: float64

# %%
pd.options.display.float_format='{:.5f}'.format

# %%
df.describe()
# Out:
#                ENTRIES            EXITS       NET_ENTRIES         NET_EXITS
# count    3716409.00000    3716409.00000     3716408.00000     3716408.00000
# mean    42026268.14910   34454790.26317          -1.89153          -0.64160
# std    214135285.58174  197156450.80183    45064898.25361    41319167.19168
# min            0.00000          0.00000 -2116018673.00000 -2111174859.00000
# 25%       301269.00000     122984.00000           8.00000           7.00000
# 50%      2129609.00000    1216656.00000          69.00000          51.00000
# 75%      6712024.00000    4591477.00000         232.00000         165.00000
# max   2129342740.00000 2124126951.00000  2121328191.00000  2118903676.00000

# %%
df.columns
# Out:
# Index(['STATION', 'TURNSTILE', 'DATE', 'TIME', 'TIMESTAMP', 'ENTRIES', 'EXITS',
#        'WEEKDAYS', 'NET_ENTRIES', 'NET_EXITS'],
#       dtype='object')

# %%
df.shape
# Out:
# (3716409, 10)

# %% [markdown]
# #Negatif deÄŸerler NET_ENTRIES ve NET_EXITSte kaÃ§ tane var

# %%
print("Negative values for NET_ENTRIES column: ")
print(len(df[df["NET_ENTRIES"]<0]))
print("Negative values for NET_EXITS column:")
print(len(df[df["NET_EXITS"]<0]))
# Out:
# Negative values for NET_ENTRIES column:
# 77645
# Negative values for NET_EXITS column:
# 70466

# %% [markdown]
# #BoÅŸ olanlara 0 ata. Negatif ve de %95 gÃ¼ven aralÄ±ÄŸÄ±nÄ±n Ã¼stÃ¼nde olan deÄŸerlere median deÄŸerlerini atadÄ±k

# %%
df['NET_ENTRIES'][df['NET_ENTRIES'] < 0] = (df["NET_ENTRIES"].median())
df['NET_EXITS'][df['NET_EXITS'] < 0] = (df["NET_EXITS"].median())
df['NET_ENTRIES'][df['NET_ENTRIES'] > (df["NET_ENTRIES"].quantile(0.95))] = (df["NET_ENTRIES"].median()) 
df['NET_EXITS'][df['NET_EXITS'] > (df["NET_EXITS"].quantile(0.95))] = (df["NET_EXITS"].median())
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_13188/3552351569.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NET_ENTRIES'][df['NET_ENTRIES'] < 0] = (df["NET_ENTRIES"].median())
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_13188/3552351569.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NET_EXITS'][df['NET_EXITS'] < 0] = (df["NET_EXITS"].median())
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_13188/3552351569.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NET_ENTRIES'][df['NET_ENTRIES'] > (df["NET_ENTRIES"].quantile(0.95))] = (df["NET_ENTRIES"].median())
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_13188/3552351569.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NET_EXITS'][df['NET_EXITS'] > (df["NET_EXITS"].quantile(0.95))] = (df["NET_EXITS"].median())

# %%
pd.options.display.float_format='{:.5f}'.format

# %%
print("Descriptive Statistics for NET_ENTRIES column:")
print(df["NET_ENTRIES"].describe())
print("Descriptive Statistics for NET_EXITS column:")
print(df["NET_EXITS"].describe())
# Out:
# Descriptive Statistics for NET_ENTRIES column:
# count   3716408.00000
# mean        127.48983
# std         157.10004
# min           0.00000
# 25%          10.00000
# 50%          69.00000
# 75%         187.00000
# max         709.00000
# Name: NET_ENTRIES, dtype: float64
# Descriptive Statistics for NET_EXITS column:
# count   3716408.00000
# mean         95.93737
# std         123.61818
# min           0.00000
# 25%           9.00000
# 50%          51.00000
# 75%         131.00000
# max         608.00000
# Name: NET_EXITS, dtype: float64

# %%
df["TRAFFIC"] = df["NET_ENTRIES"] + df["NET_EXITS"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3716409 entries, 0 to 3716408
# Data columns (total 11 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   STATION      object
#  1   TURNSTILE    object
#  2   DATE         object
#  3   TIME         object
#  4   TIMESTAMP    datetime64[ns]
#  5   ENTRIES      int64
#  6   EXITS        int64
#  7   WEEKDAYS     object
#  8   NET_ENTRIES  float64
#  9   NET_EXITS    float64
#  10  TRAFFIC      float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(5)
# memory usage: 340.2+ MB

# %%
df.head(50)
# Out:
#    STATION           TURNSTILE        DATE      TIME           TIMESTAMP  \
# 0    59 ST  A002-R051-02-00-00  04/27/2019  00:00:00 2019-04-27 00:00:00
# 1    59 ST  A002-R051-02-00-00  04/27/2019  04:00:00 2019-04-27 04:00:00
# 2    59 ST  A002-R051-02-00-00  04/27/2019  08:00:00 2019-04-27 08:00:00
# 3    59 ST  A002-R051-02-00-00  04/27/2019  12:00:00 2019-04-27 12:00:00
# 4    59 ST  A002-R051-02-00-00  04/27/2019  16:00:00 2019-04-27 16:00:00
# 5    59 ST  A002-R051-02-00-00  04/27/2019  20:00:00 2019-04-27 20:00:00
# 6    59 ST  A002-R051-02-00-00  04/28/2019  00:00:00 2019-04-28 00:00:00
# 7    59 ST  A002-R051-02-00-00  04/28/2019  04:00:00 2019-04-28 04:00:00
# 8    59 ST  A002-R051-02-00-00  04/28/2019  08:00:00 2019-04-28 08:00:00
# 9    59 ST  A002-R051-02-00-00  04/28/2019  12:00:00 2019-04-28 12:00:00
# 10   59 ST  A002-R051-02-00-00  04/28/2019  16:00:00 2019-04-28 16:00:00
# 36  7042880  2387242     Friday     13.00000    2.00000  15.00000
# 37  7042893  2387244     Friday     31.00000   89.00000 120.00000
# 38  7042924  2387333     Friday     63.00000  194.00000 257.00000
# 39  7042987  2387527     Friday     48.00000   44.00000  92.00000
# 40  7043035  2387571     Friday     14.00000    8.00000  22.00000
# 41  7043049  2387579     Friday    354.00000   52.00000 406.00000
# 42  7043403  2387631     Friday     69.00000   43.00000 112.00000
# 43  7044206  2387674     Friday     69.00000   51.00000 120.00000
# 44  6268264  1405759   Saturday     11.00000    3.00000  14.00000
# 45  6268275  1405762   Saturday     12.00000   13.00000  25.00000
# 46  6268287  1405775   Saturday     86.00000   40.00000 126.00000
# 47  6268373  1405815   Saturday    222.00000   52.00000 274.00000
# 48  6268595  1405867   Saturday    255.00000   27.00000 282.00000
# 49  6268850  1405894   Saturday    148.00000   11.00000 159.00000

# %%
df.TRAFFIC.describe()
# Out:
# count   3716408.00000
# mean        223.42719
# std         233.22139
# min           0.00000
# 25%          31.00000
# 50%         140.00000
# 75%         350.00000
# max        1314.00000
# Name: TRAFFIC, dtype: float64

# %%
df.TRAFFIC.value_counts()
# Out:
# 0.00000       449669
# 120.00000     122257
# 1.00000        44781
# 2.00000        25065
# 3.00000        20184
#                ...
# 1303.00000         1
# 1311.00000         1
# 1294.00000         1
# 1302.00000         1
# 1309.00000         1
# Name: TRAFFIC, Length: 1315, dtype: int64

# %%
df['WEEKDAYS_INDEX'] = pd.to_datetime(df['DATE']).dt.weekday
df.head()
# Out:
#   STATION           TURNSTILE        DATE      TIME           TIMESTAMP  \
# 0   59 ST  A002-R051-02-00-00  04/27/2019  00:00:00 2019-04-27 00:00:00
# 1   59 ST  A002-R051-02-00-00  04/27/2019  04:00:00 2019-04-27 04:00:00
# 2   59 ST  A002-R051-02-00-00  04/27/2019  08:00:00 2019-04-27 08:00:00
# 3   59 ST  A002-R051-02-00-00  04/27/2019  12:00:00 2019-04-27 12:00:00
# 4   59 ST  A002-R051-02-00-00  04/27/2019  16:00:00 2019-04-27 16:00:00
#
#    ENTRIES    EXITS  WEEKDAYS  NET_ENTRIES  NET_EXITS   TRAFFIC  \
# 0  7035249  2384833  Saturday     20.00000    7.00000  27.00000
# 1  7035269  2384840  Saturday     23.00000   35.00000  58.00000
# 2  7035292  2384875  Saturday    100.00000   76.00000 176.00000
# 3  7035392  2384951  Saturday    259.00000   69.00000 328.00000
# 4  7035651  2385020  Saturday    279.00000   50.00000 329.00000
#
#    WEEKDAYS_INDEX
# 0               5
# 1               5
# 2               5
# 3               5
# 4               5

# %%
busiest_stations = df.groupby("STATION").sum().sort_values("TRAFFIC", ascending = False).reset_index().head(10)
busiest_stations.head(10)
# Out:
#            STATION        ENTRIES          EXITS    NET_ENTRIES     NET_EXITS  \
# 0   34 ST-PENN STA  3075382239813  3259677091046 12388902.00000 9976904.00000
# 1            23 ST  4119692981993  3548061882651  8399416.00000 7079028.00000
# 2        FULTON ST  3685079703737  3689735092510  7761980.00000 6291763.00000
# 3  GRD CNTRL-42 ST  2059683341527  2605718469267  6877354.00000 6030201.00000
# 4  34 ST-HERALD SQ  3568603382051  4473905207809  6359414.00000 6369902.00000
# 5   TIMES SQ-42 ST  4669563752765  3581226025185  7041605.00000 5561670.00000
# 6  42 ST-PORT AUTH  5814588062658  4788851661006  7615267.00000 4842498.00000
# 7           125 ST  5038136907157  3004351884007  6593112.00000 5481421.00000
# 8            86 ST  1625194760875  1925952876061  7007730.00000 4693120.00000
# 9         CANAL ST  3077303670208  4126953227727  5644325.00000 5010454.00000
#
#          TRAFFIC  WEEKDAYS_INDEX
# 0 22365806.00000          233936
# 1 15478444.00000          164826
# 2 14053743.00000          222561
# 3 12907555.00000          156469
# 4 12729316.00000          125070
# 5 12603275.00000          118001
# 6 12457765.00000          116443
# 7 12074533.00000           99274
# 8 11700850.00000          141538
# 9 10654779.00000          132420

# %%
plt.figure(figsize=(10,6),dpi=200)
plt.bar(busiest_stations.STATION, busiest_stations.TRAFFIC)
plt.xticks(rotation=45, ha='right');
plt.xlabel("STATIONS")
plt.ylabel("TOTAL TRAFFIC")
plt.title("TOP 10 BUSIEST STATIONS 2019", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOP 10 BUSIEST STATIONS 2019')

# %%
plt.figure(figsize=(10,6),dpi=200)
plt.barh(busiest_stations.STATION, busiest_stations.TRAFFIC, color=['blue', 'orange', 'orange', 'orange', 'orange','orange','orange','orange','orange','orange']);
plt.gca().invert_yaxis()
plt.xlabel("TOTAL TRAFFIC")
plt.ylabel(" ")
plt.title("TOP 10 BUSIEST STATIONS 2019", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOP 10 BUSIEST STATIONS 2019')

# %%
plt.figure(figsize=(10,6),dpi=200)
sns.set_style("whitegrid")
sns.barplot(y = 'STATION', x = 'TRAFFIC', data = busiest_stations)
plt.xlabel("TOTAL TRAFFIC")
plt.ylabel(" ")
plt.title("TOP 10 BUSIEST STATIONS 2019", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOP 10 BUSIEST STATIONS 2019')

# %%
busiest_days = df.groupby("WEEKDAYS").sum().sort_values("WEEKDAYS_INDEX", ascending = True).reset_index()
busiest_days
# Out:
#     WEEKDAYS         ENTRIES           EXITS    NET_ENTRIES      NET_EXITS  \
# 0     Monday  22449368945834  18351499141423 73274523.00000 54627686.00000
# 1    Tuesday  22508923944697  18501421261446 76481472.00000 56719256.00000
# 2  Wednesday  22336204663611  18308826745751 77033786.00000 57232141.00000
# 3   Thursday  22254280207359  18244421990973 75734924.00000 56365208.00000
# 4     Friday  22530866197073  18544209439816 74868863.00000 54173278.00000
# 5   Saturday  22071788518390  18084528599786 53080374.00000 42081184.00000
# 6     Sunday  22035368708777  18013185447944 43330264.00000 35343653.00000
#
#           TRAFFIC  WEEKDAYS_INDEX
# 0 127902209.00000               0
# 1 133200728.00000          535993
# 2 134265927.00000         1065710
# 3 132100132.00000         1590507
# 4 129042141.00000         2136636
# 5  95161558.00000         2624880
# 6  78673917.00000         3151002

# %%
plt.figure(figsize=(10,6),dpi=200)
plt.bar(busiest_days.WEEKDAYS, busiest_days.TRAFFIC, color=['red' if x < 50000000 else 'blue' for x in busiest_days.TRAFFIC.values]);
plt.xlabel(" ")
plt.ylabel("TOTAL TRAFFIC")
plt.title("TOTAL TRAFFIC ACCORDING TO WEEKDAYS 2019", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOTAL TRAFFIC ACCORDING TO WEEKDAYS 2019')

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.set_style("whitegrid")
sns.barplot(x = 'WEEKDAYS', y = 'TRAFFIC', data = busiest_days)
plt.ylabel("TOTAL TRAFFIC")
plt.xlabel(" ")
plt.title("TOTAL TRAFFIC ACCORDING TO WEEKDAYS 2019", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOTAL TRAFFIC ACCORDING TO WEEKDAYS 2019')

# %%
busiest_times = df.groupby("TIME").sum().sort_values("TRAFFIC", ascending = False).reset_index()

# %%
for i in range(len(busiest_times)):
    
    if busiest_times['TIME'][i] < ('04:00:00'):
        busiest_times['TIME'][i] =  ('00:00 - 04:00')
    
    elif ('04:00:00') <= busiest_times['TIME'][i] < ('08:00:00'):
        busiest_times['TIME'][i] =  ('04:00 - 08:00')
    
    elif ('08:00:00') <= busiest_times['TIME'][i] < ('12:00:00'):
        busiest_times['TIME'][i] =  ('08:00 - 12:00')
    
    elif ('12:00:00') <= busiest_times['TIME'][i] < ('16:00:00'):
        busiest_times['TIME'][i] =  ('12:00 - 16:00')
    
    elif ('16:00:00') <= busiest_times['TIME'][i] < ('20:00:00'):
        busiest_times['TIME'][i] =  ('16:00 - 20:00')
    
    elif ('20:00:00') <= busiest_times['TIME'][i]:
        busiest_times['TIME'][i] =  ('20:00 - 00:00')
        
    i = i + 1
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_13188/3535484847.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   busiest_times['TIME'][i] =  ('16:00 - 20:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_13188/3535484847.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   busiest_times['TIME'][i] =  ('12:00 - 16:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_13188/3535484847.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   busiest_times['TIME'][i] =  ('08:00 - 12:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_13188/3535484847.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   busiest_times['TIME'][i] =  ('20:00 - 00:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_13188/3535484847.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   busiest_times['TIME'][i] =  ('04:00 - 08:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_13188/3535484847.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   busiest_times['TIME'][i] =  ('00:00 - 04:00')

# %%
busiest_times
# Out:
#                 TIME         ENTRIES           EXITS    NET_ENTRIES  \
# 0      16:00 - 20:00  15602370710032  13305192406982 62937625.00000
# 1      12:00 - 16:00  15575683810406  13279525273329 62950767.00000
# 2      08:00 - 12:00  15604366883011  13305185399584 55877036.00000
# 3      12:00 - 16:00   8787153351317   6725020916799 43844867.00000
# 4      16:00 - 20:00   8792420983052   6730988563320 37573065.00000
# ...              ...             ...             ...            ...
# 72156  00:00 - 04:00               3               0        0.00000
# 72157  16:00 - 20:00           17801            1647        0.00000
# 72158  16:00 - 20:00           17068            1589        0.00000
# 72159  04:00 - 08:00           54976          186932        0.00000
# 72160  00:00 - 04:00              44            2654        0.00000
#
#            NET_EXITS         TRAFFIC  WEEKDAYS_INDEX
# 0     47508429.00000 110446054.00000          935321
# 1     43768601.00000 106719368.00000          935220
# 2     39229756.00000  95106792.00000          935412
# 3     32226450.00000  76071317.00000          691301
# 4     33159580.00000  70732645.00000          691364
# ...              ...             ...             ...
# 72156        0.00000         0.00000               9
# 72157        0.00000         0.00000               2
# 72158        0.00000         0.00000               1
# 72159        0.00000         0.00000               6
# 72160        0.00000         0.00000               0
#
# [72161 rows x 7 columns]

# %%
busiest_times = busiest_times.groupby("TIME").sum().sort_values("TRAFFIC", ascending = False).reset_index()
busiest_times
# Out:
#             TIME         ENTRIES           EXITS     NET_ENTRIES  \
# 0  12:00 - 16:00  25870142271468  21120918020631 117740284.00000
# 1  16:00 - 20:00  25864013203364  21214309796093 109235685.00000
# 2  08:00 - 12:00  27350586875454  22499631266623 104494145.00000
# 3  04:00 - 08:00  25922817678399  21268597017184  78311273.00000
# 4  20:00 - 00:00  25600076452891  20996313784729  52527515.00000
# 5  00:00 - 04:00  25579164704165  20948322741879  11495304.00000
#
#        NET_EXITS         TRAFFIC  WEEKDAYS_INDEX
# 0 84097459.00000 201837743.00000         1840691
# 1 87630253.00000 196865938.00000         1844936
# 2 74357512.00000 178851657.00000         1910172
# 3 50600665.00000 128911938.00000         1844860
# 4 47340356.00000  99867871.00000         1835225
# 5 12516161.00000  24011465.00000         1828844

# %%
plt.figure(figsize=(10,6),dpi=200)
sns.set_style("whitegrid")

# %%
sns.barplot(x = 'TIME', y = 'TRAFFIC', data = busiest_times, order = ['00:00 - 04:00', '04:00 - 08:00', '08:00 - 12:00', '12:00 - 16:00', '16:00 - 20:00', '20:00 - 00:00'])
plt.xlabel(" ")
plt.ylabel("TOTAL TRAFFIC")
plt.title("TOTAL TRAFFIC ACCORDING TO TIMES OF DAY 2019", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOTAL TRAFFIC ACCORDING TO TIMES OF DAY 2019')

# %%
plt.figure(figsize=(12,8),dpi=200)
plt.pie(busiest_times.TRAFFIC,labels= busiest_times.TIME, autopct='%.0f%%', explode = [.1,0,0,0,0,0])
plt.title("TOTAL TRAFFIC ACCORDING TO TIMES OF DAY 2019", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOTAL TRAFFIC ACCORDING TO TIMES OF DAY 2019')

# %%
busiest_stations_weekdays = df.groupby(['STATION','WEEKDAYS',"WEEKDAYS_INDEX"]).agg({'TRAFFIC':'sum'}).reset_index()[["STATION","WEEKDAYS","TRAFFIC","WEEKDAYS_INDEX"]]
busiest_stations_weekdays
# Out:
#         STATION   WEEKDAYS      TRAFFIC  WEEKDAYS_INDEX
# 0          1 AV     Friday 295285.00000               4
# 1          1 AV     Monday 333532.00000               0
# 2          1 AV   Saturday 221920.00000               5
# 3          1 AV     Sunday 194828.00000               6
# 4          1 AV   Thursday 331738.00000               3
# ...         ...        ...          ...             ...
# 2641  ZEREGA AV   Saturday  45266.00000               5
# 2642  ZEREGA AV     Sunday  33962.00000               6
# 2643  ZEREGA AV   Thursday  89951.00000               3
# 2644  ZEREGA AV    Tuesday  92549.00000               1
# 2645  ZEREGA AV  Wednesday  94140.00000               2
#
# [2646 rows x 4 columns]

# %%
station1 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "34 ST-PENN STA" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station1
# Out:
#             STATION   WEEKDAYS       TRAFFIC  WEEKDAYS_INDEX
# 428  34 ST-PENN STA     Monday 3400807.00000               0
# 432  34 ST-PENN STA    Tuesday 3494045.00000               1
# 433  34 ST-PENN STA  Wednesday 3574775.00000               2
# 431  34 ST-PENN STA   Thursday 3520890.00000               3
# 427  34 ST-PENN STA     Friday 3475216.00000               4
# 429  34 ST-PENN STA   Saturday 2598660.00000               5
# 430  34 ST-PENN STA     Sunday 2301413.00000               6

# %%
station2 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "23 ST" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station2
# Out:
#     STATION   WEEKDAYS       TRAFFIC  WEEKDAYS_INDEX
# 323   23 ST     Monday 2407332.00000               0
# 327   23 ST    Tuesday 2552875.00000               1
# 328   23 ST  Wednesday 2558901.00000               2
# 326   23 ST   Thursday 2531748.00000               3
# 322   23 ST     Friday 2360841.00000               4
# 324   23 ST   Saturday 1703662.00000               5
# 325   23 ST     Sunday 1363085.00000               6

# %%
station3 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "FULTON ST" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station3
# Out:
#         STATION   WEEKDAYS       TRAFFIC  WEEKDAYS_INDEX
# 1576  FULTON ST     Monday 2216430.00000               0
# 1580  FULTON ST    Tuesday 2296791.00000               1
# 1581  FULTON ST  Wednesday 2332149.00000               2
# 1579  FULTON ST   Thursday 2319352.00000               3
# 1575  FULTON ST     Friday 2396146.00000               4
# 1577  FULTON ST   Saturday 1416662.00000               5
# 1578  FULTON ST     Sunday 1076213.00000               6

# %%
station4 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "GRD CNTRL-42 ST" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station4
# Out:
#               STATION   WEEKDAYS       TRAFFIC  WEEKDAYS_INDEX
# 1625  GRD CNTRL-42 ST     Monday 1959905.00000               0
# 1629  GRD CNTRL-42 ST    Tuesday 1992550.00000               1
# 1630  GRD CNTRL-42 ST  Wednesday 2057123.00000               2
# 1628  GRD CNTRL-42 ST   Thursday 1993613.00000               3
# 1624  GRD CNTRL-42 ST     Friday 2017764.00000               4
# 1626  GRD CNTRL-42 ST   Saturday 1565007.00000               5
# 1627  GRD CNTRL-42 ST     Sunday 1321593.00000               6

# %%
station5 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "34 ST-HERALD SQ" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station5
# Out:
#              STATION   WEEKDAYS       TRAFFIC  WEEKDAYS_INDEX
# 414  34 ST-HERALD SQ     Monday 1863520.00000               0
# 418  34 ST-HERALD SQ    Tuesday 1910607.00000               1
# 419  34 ST-HERALD SQ  Wednesday 1925332.00000               2
# 417  34 ST-HERALD SQ   Thursday 1909788.00000               3
# 413  34 ST-HERALD SQ     Friday 1709720.00000               4
# 415  34 ST-HERALD SQ   Saturday 1815671.00000               5
# 416  34 ST-HERALD SQ     Sunday 1594678.00000               6

# %%
station6 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "TIMES SQ-42 ST" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station6
# Out:
#              STATION   WEEKDAYS       TRAFFIC  WEEKDAYS_INDEX
# 2465  TIMES SQ-42 ST     Monday 1919977.00000               0
# 2469  TIMES SQ-42 ST    Tuesday 1905549.00000               1
# 2470  TIMES SQ-42 ST  Wednesday 1894251.00000               2
# 2468  TIMES SQ-42 ST   Thursday 1883704.00000               3
# 2464  TIMES SQ-42 ST     Friday 1760469.00000               4
# 2466  TIMES SQ-42 ST   Saturday 1706614.00000               5
# 2467  TIMES SQ-42 ST     Sunday 1532711.00000               6

# %%
station7 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "42 ST-PORT AUTH" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station7
# Out:
#              STATION   WEEKDAYS       TRAFFIC  WEEKDAYS_INDEX
# 477  42 ST-PORT AUTH     Monday 1798072.00000               0
# 481  42 ST-PORT AUTH    Tuesday 1827386.00000               1
# 482  42 ST-PORT AUTH  Wednesday 1869095.00000               2
# 480  42 ST-PORT AUTH   Thursday 1850508.00000               3
# 476  42 ST-PORT AUTH     Friday 1742499.00000               4
# 478  42 ST-PORT AUTH   Saturday 1781772.00000               5
# 479  42 ST-PORT AUTH     Sunday 1588433.00000               6

# %%
station8 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "125 ST" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station8
# Out:
#    STATION   WEEKDAYS       TRAFFIC  WEEKDAYS_INDEX
# 64  125 ST     Monday 1845973.00000               0
# 68  125 ST    Tuesday 1931742.00000               1
# 69  125 ST  Wednesday 1937519.00000               2
# 67  125 ST   Thursday 1886552.00000               3
# 63  125 ST     Friday 1716172.00000               4
# 65  125 ST   Saturday 1466534.00000               5
# 66  125 ST     Sunday 1290041.00000               6

# %%
station9 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "86 ST" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station9
# Out:
#     STATION   WEEKDAYS       TRAFFIC  WEEKDAYS_INDEX
# 771   86 ST     Monday 1794997.00000               0
# 775   86 ST    Tuesday 1889018.00000               1
# 776   86 ST  Wednesday 1889860.00000               2
# 774   86 ST   Thursday 1848700.00000               3
# 770   86 ST     Friday 1750947.00000               4
# 772   86 ST   Saturday 1374513.00000               5
# 773   86 ST     Sunday 1152815.00000               6

# %%
station10 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "CANAL ST" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station10
# Out:
#        STATION   WEEKDAYS       TRAFFIC  WEEKDAYS_INDEX
# 1205  CANAL ST     Monday 1585812.00000               0
# 1209  CANAL ST    Tuesday 1662154.00000               1
# 1210  CANAL ST  Wednesday 1667883.00000               2
# 1208  CANAL ST   Thursday 1676541.00000               3
# 1204  CANAL ST     Friday 1606828.00000               4
# 1206  CANAL ST   Saturday 1352896.00000               5
# 1207  CANAL ST     Sunday 1102665.00000               6

# %%
stations = [station1, station2, station3 ,station4 ,station5]
stations_for_tourists = pd.concat(stations)
stations_for_tourists
# Out:
#               STATION   WEEKDAYS       TRAFFIC  WEEKDAYS_INDEX
# 428    34 ST-PENN STA     Monday 3400807.00000               0
# 432    34 ST-PENN STA    Tuesday 3494045.00000               1
# 433    34 ST-PENN STA  Wednesday 3574775.00000               2
# 431    34 ST-PENN STA   Thursday 3520890.00000               3
# 427    34 ST-PENN STA     Friday 3475216.00000               4
# 429    34 ST-PENN STA   Saturday 2598660.00000               5
# 430    34 ST-PENN STA     Sunday 2301413.00000               6
# 323             23 ST     Monday 2407332.00000               0
# 327             23 ST    Tuesday 2552875.00000               1
# 328             23 ST  Wednesday 2558901.00000               2
# 326             23 ST   Thursday 2531748.00000               3
# 322             23 ST     Friday 2360841.00000               4
# 324             23 ST   Saturday 1703662.00000               5
# 325             23 ST     Sunday 1363085.00000               6
# 1576        FULTON ST     Monday 2216430.00000               0
# 1580        FULTON ST    Tuesday 2296791.00000               1
# 1581        FULTON ST  Wednesday 2332149.00000               2
# 1579        FULTON ST   Thursday 2319352.00000               3
# 1575        FULTON ST     Friday 2396146.00000               4
# 1577        FULTON ST   Saturday 1416662.00000               5
# 1578        FULTON ST     Sunday 1076213.00000               6
# 1625  GRD CNTRL-42 ST     Monday 1959905.00000               0
# 1629  GRD CNTRL-42 ST    Tuesday 1992550.00000               1
# 1630  GRD CNTRL-42 ST  Wednesday 2057123.00000               2
# 1628  GRD CNTRL-42 ST   Thursday 1993613.00000               3
# 1624  GRD CNTRL-42 ST     Friday 2017764.00000               4
# 1626  GRD CNTRL-42 ST   Saturday 1565007.00000               5
# 1627  GRD CNTRL-42 ST     Sunday 1321593.00000               6
# 414   34 ST-HERALD SQ     Monday 1863520.00000               0
# 418   34 ST-HERALD SQ    Tuesday 1910607.00000               1
# 419   34 ST-HERALD SQ  Wednesday 1925332.00000               2
# 417   34 ST-HERALD SQ   Thursday 1909788.00000               3
# 413   34 ST-HERALD SQ     Friday 1709720.00000               4
# 415   34 ST-HERALD SQ   Saturday 1815671.00000               5
# 416   34 ST-HERALD SQ     Sunday 1594678.00000               6

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.lineplot(data=stations_for_tourists, x="WEEKDAYS", y="TRAFFIC", hue="STATION")
ax.axvspan("Wednesday", "Thursday", alpha=0.15, color='blue')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.title("TOTAL TRAFFIC OF TOP 5 STATIONS BY WEEKDAYS 2019", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOTAL TRAFFIC OF TOP 5 STATIONS BY WEEKDAYS 2019')

# %%
Most_Busiest_Station = df[df['STATION'] == '34 ST-PENN STA']
Most_Busiest_Station
# Out:
#                 STATION           TURNSTILE        DATE      TIME  \
# 52864    34 ST-PENN STA  N067-R012-00-00-00  04/27/2019  00:00:00
# 52865    34 ST-PENN STA  N067-R012-00-00-00  04/27/2019  04:00:00
# 52866    34 ST-PENN STA  N067-R012-00-00-00  04/27/2019  08:00:00
# 52867    34 ST-PENN STA  N067-R012-00-00-00  04/27/2019  12:00:00
# 52868    34 ST-PENN STA  N067-R012-00-00-00  04/27/2019  16:00:00
# ...                 ...                 ...         ...       ...
# 3649204  34 ST-PENN STA  R142-R293-01-06-01  08/30/2019  06:00:00
# 3649205  34 ST-PENN STA  R142-R293-01-06-01  08/30/2019  10:00:00
# 3649206  34 ST-PENN STA  R142-R293-01-06-01  08/30/2019  14:00:00
# 3649207  34 ST-PENN STA  R142-R293-01-06-01  08/30/2019  18:00:00
# 3649208  34 ST-PENN STA  R142-R293-01-06-01  08/30/2019  22:00:00
#
#                   TIMESTAMP   ENTRIES     EXITS  WEEKDAYS  NET_ENTRIES  \
# 52864   2019-04-27 00:00:00      6226     18077  Saturday      4.00000
# 52865   2019-04-27 04:00:00      6230     18081  Saturday     13.00000
# 52866   2019-04-27 08:00:00      6243     18160  Saturday     63.00000
# 52867   2019-04-27 12:00:00      6306     18347  Saturday    102.00000
# 52868   2019-04-27 16:00:00      6408     18614  Saturday     94.00000
# ...                     ...       ...       ...       ...          ...
# 3649204 2019-08-30 06:00:00  67920366  18458536    Friday     94.00000
# 3649205 2019-08-30 10:00:00  67920460  18458859    Friday    160.00000
# 3649206 2019-08-30 14:00:00  67920620  18459164    Friday    207.00000
# 3649207 2019-08-30 18:00:00  67920827  18459523    Friday    129.00000
# 3649208 2019-08-30 22:00:00  67920956  18459785    Friday     69.00000
#
#          NET_EXITS   TRAFFIC  WEEKDAYS_INDEX
# 52864      4.00000   8.00000               5
# 52865     79.00000  92.00000               5
# 52866    187.00000 250.00000               5
# 52867    267.00000 369.00000               5
# 52868    209.00000 303.00000               5
# ...            ...       ...             ...
# 3649204  323.00000 417.00000               4
# 3649205  305.00000 465.00000               4
# 3649206  359.00000 566.00000               4
# 3649207  262.00000 391.00000               4
# 3649208   51.00000 120.00000               4
#
# [78315 rows x 12 columns]

# %%
for i in range(len(Most_Busiest_Station['TIME'].index)):
    
    if Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] < ('04:00:00'):
        Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('00:00 - 04:00')
    
    elif ('04:00:00') <= Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] < ('08:00:00'):
        Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('04:00 - 08:00')
    
    elif ('08:00:00') <= Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] < ('12:00:00'):
        Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('08:00 - 12:00')
    
    elif ('12:00:00') <= Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] < ('16:00:00'):
        Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('12:00 - 16:00')
    
    elif ('16:00:00') <= Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] < ('20:00:00'):
        Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('16:00 - 20:00')
    
    elif ('20:00:00') <= Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]]:
        Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('20:00 - 00:00')
        
    i = i + 1
    
Most_Busiest_Station
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_13188/983574974.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('00:00 - 04:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_13188/983574974.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('04:00 - 08:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_13188/983574974.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('08:00 - 12:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_13188/983574974.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('12:00 - 16:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_13188/983574974.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('16:00 - 20:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_13188/983574974.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('20:00 - 00:00')
#                 STATION           TURNSTILE        DATE           TIME  \
# 52864    34 ST-PENN STA  N067-R012-00-00-00  04/27/2019  00:00 - 04:00
# 52865    34 ST-PENN STA  N067-R012-00-00-00  04/27/2019  04:00 - 08:00
# 52866    34 ST-PENN STA  N067-R012-00-00-00  04/27/2019  08:00 - 12:00
# 52867    34 ST-PENN STA  N067-R012-00-00-00  04/27/2019  12:00 - 16:00
# 52868    34 ST-PENN STA  N067-R012-00-00-00  04/27/2019  16:00 - 20:00
# ...                 ...                 ...         ...            ...
# 3649204  34 ST-PENN STA  R142-R293-01-06-01  08/30/2019  04:00 - 08:00
# 3649205  34 ST-PENN STA  R142-R293-01-06-01  08/30/2019  08:00 - 12:00
# 3649206  34 ST-PENN STA  R142-R293-01-06-01  08/30/2019  12:00 - 16:00
# 3649207  34 ST-PENN STA  R142-R293-01-06-01  08/30/2019  16:00 - 20:00
# 3649208  34 ST-PENN STA  R142-R293-01-06-01  08/30/2019  20:00 - 00:00
#
#                   TIMESTAMP   ENTRIES     EXITS  WEEKDAYS  NET_ENTRIES  \
# 52864   2019-04-27 00:00:00      6226     18077  Saturday      4.00000
# 52865   2019-04-27 04:00:00      6230     18081  Saturday     13.00000
# 52866   2019-04-27 08:00:00      6243     18160  Saturday     63.00000
# 52867   2019-04-27 12:00:00      6306     18347  Saturday    102.00000
# 52868   2019-04-27 16:00:00      6408     18614  Saturday     94.00000
# ...                     ...       ...       ...       ...          ...
# 3649204 2019-08-30 06:00:00  67920366  18458536    Friday     94.00000
# 3649205 2019-08-30 10:00:00  67920460  18458859    Friday    160.00000
# 3649206 2019-08-30 14:00:00  67920620  18459164    Friday    207.00000
# 3649207 2019-08-30 18:00:00  67920827  18459523    Friday    129.00000
# 3649208 2019-08-30 22:00:00  67920956  18459785    Friday     69.00000
#
#          NET_EXITS   TRAFFIC  WEEKDAYS_INDEX
# 52864      4.00000   8.00000               5
# 52865     79.00000  92.00000               5
# 52866    187.00000 250.00000               5
# 52867    267.00000 369.00000               5
# 52868    209.00000 303.00000               5
# ...            ...       ...             ...
# 3649204  323.00000 417.00000               4
# 3649205  305.00000 465.00000               4
# 3649206  359.00000 566.00000               4
# 3649207  262.00000 391.00000               4
# 3649208   51.00000 120.00000               4
#
# [78315 rows x 12 columns]

# %%
BT_of_MBS = Most_Busiest_Station.groupby(["TIME","WEEKDAYS","WEEKDAYS_INDEX"]).agg({'TRAFFIC':'sum'}).reset_index()[["TIME","WEEKDAYS","TRAFFIC","WEEKDAYS_INDEX"]]
BT_of_MBS
# Out:
#              TIME   WEEKDAYS      TRAFFIC  WEEKDAYS_INDEX
# 0   00:00 - 04:00     Friday  80195.00000               4
# 1   00:00 - 04:00     Monday  67216.00000               0
# 2   00:00 - 04:00   Saturday 103730.00000               5
# 3   00:00 - 04:00     Sunday  85815.00000               6
# 4   00:00 - 04:00   Thursday  73882.00000               3
# 5   00:00 - 04:00    Tuesday  70043.00000               1
# 6   00:00 - 04:00  Wednesday  71799.00000               2
# 7   04:00 - 08:00     Friday 540494.00000               4
# 8   04:00 - 08:00     Monday 505186.00000               0
# 9   04:00 - 08:00   Saturday 206001.00000               5
# 10  04:00 - 08:00     Sunday 147110.00000               6
# 11  04:00 - 08:00   Thursday 513920.00000               3
# 12  04:00 - 08:00    Tuesday 517221.00000               1
# 13  04:00 - 08:00  Wednesday 532590.00000               2
# 14  08:00 - 12:00     Friday 854624.00000               4
# 15  08:00 - 12:00     Monday 770615.00000               0
# 16  08:00 - 12:00   Saturday 543241.00000               5
# 17  08:00 - 12:00     Sunday 469680.00000               6
# 18  08:00 - 12:00   Thursday 755437.00000               3
# 19  08:00 - 12:00    Tuesday 765283.00000               1
# 20  08:00 - 12:00  Wednesday 811898.00000               2
# 21  12:00 - 16:00     Friday 876626.00000               4
# 22  12:00 - 16:00     Monday 773815.00000               0
# 23  12:00 - 16:00   Saturday 665872.00000               5
# 24  12:00 - 16:00     Sunday 615423.00000               6
# 25  12:00 - 16:00   Thursday 781869.00000               3
# 26  12:00 - 16:00    Tuesday 781754.00000               1
# 27  12:00 - 16:00  Wednesday 784751.00000               2
# 28  16:00 - 20:00     Friday 900262.00000               4
# 29  16:00 - 20:00     Monday 898770.00000               0
# 30  16:00 - 20:00   Saturday 662872.00000               5
# 31  16:00 - 20:00     Sunday 625305.00000               6
# 32  16:00 - 20:00   Thursday 915951.00000               3
# 33  16:00 - 20:00    Tuesday 924747.00000               1
# 34  16:00 - 20:00  Wednesday 922005.00000               2
# 35  20:00 - 00:00     Friday 223015.00000               4
# 36  20:00 - 00:00     Monday 385205.00000               0
# 37  20:00 - 00:00   Saturday 416944.00000               5
# 38  20:00 - 00:00     Sunday 358080.00000               6
# 39  20:00 - 00:00   Thursday 479831.00000               3
# 40  20:00 - 00:00    Tuesday 434997.00000               1
# 41  20:00 - 00:00  Wednesday 451732.00000               2

# %%
plt.figure(figsize=(12,8),dpi=200)
revels = BT_of_MBS.pivot("TIME", "WEEKDAYS_INDEX", "TRAFFIC")
revels.columns = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
ax = sns.heatmap(revels, linewidths=0.4, cmap="Oranges")
ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
plt.xlabel(' ')
plt.ylabel(' ')
plt.title("BUSIEST DAYS AND TIMES FOR 34 ST-PENN STATION 2019", family='serif',fontsize = 15,loc='center',color='Red')
plt.show()

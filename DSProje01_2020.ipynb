# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

# %%
df0 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200502.txt')
df0 = pd.DataFrame(df0)

# %%
df1 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200509.txt')
df1 = pd.DataFrame(df1)

# %%
df2 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200516.txt')
df2 = pd.DataFrame(df2)

# %%
df3 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200523.txt')
df3 = pd.DataFrame(df3)

# %%
df4 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200530.txt')
df4 = pd.DataFrame(df4)

# %%
df5 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200606.txt')
df5 = pd.DataFrame(df5)

# %%
df6 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200613.txt')
df6 = pd.DataFrame(df6)

# %%
df7 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200620.txt')
df7 = pd.DataFrame(df7)

# %%
df8 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200627.txt')
df8 = pd.DataFrame(df8)

# %%
df9 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200704.txt')
df9 = pd.DataFrame(df9)

# %%
df10 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200711.txt')
df10 = pd.DataFrame(df10)

# %%
df11 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200718.txt')
df11 = pd.DataFrame(df11)

# %%
df12 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200725.txt')
df12 = pd.DataFrame(df12)

# %%
df13 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200801.txt')
df13 = pd.DataFrame(df13)

# %%
df14 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200808.txt')
df14 = pd.DataFrame(df14)

# %%
df15 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200815.txt')
df15 = pd.DataFrame(df15)

# %%
df16 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200822.txt')
df16 = pd.DataFrame(df16)

# %%
df17 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200829.txt')
df17 = pd.DataFrame(df17)

# %%
df = pd.concat([df0, df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17], ignore_index = True)

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7415454
# 1  REGULAR  7415454
# 2  REGULAR  7415459
# 3  REGULAR  7415468
# 4  REGULAR  7415480
#
#    EXITS
# 0                                            2518022
# 1                                            2518022
# 2                                            2518033
# 3                                            2518044
# 4                                            2518056

# %%
df.tail()
# Out:
#            C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 3741609  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/28/2020
# 3741610  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/28/2020
# 3741611  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/28/2020
# 3741612  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/28/2020
# 3741613  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/28/2020
#
#              TIME     DESC  ENTRIES  \
# 3741609  05:00:00  REGULAR     5554
# 3741610  09:00:00  REGULAR     5554
# 3741611  13:00:00  REGULAR     5554
# 3741612  17:00:00  REGULAR     5554
# 3741613  21:00:00  REGULAR     5554
#
#          EXITS
# 3741609                                                540
# 3741610                                                540
# 3741611                                                540
# 3741612                                                540
# 3741613                                                540

# %%
print(df.isnull().sum()) ###null deÄŸerleri kontrol ediyoruz
# Out:
# C/A                                                                     0
# UNIT                                                                    0
# SCP                                                                     0
# STATION                                                                 0
# LINENAME                                                                0
# DIVISION                                                                0
# DATE                                                                    0
# TIME                                                                    0
# DESC                                                                    0
# ENTRIES                                                                 0
# EXITS                                                                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
df.columns=df.columns.str.strip()

# %%
df['TIMESTAMP'] = pd.to_datetime(df['DATE'] + ' ' + df['TIME'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3741614 entries, 0 to 3741613
# Data columns (total 12 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   C/A        object
#  1   UNIT       object
#  2   SCP        object
#  3   STATION    object
#  4   LINENAME   object
#  5   DIVISION   object
#  6   DATE       object
#  7   TIME       object
#  8   DESC       object
#  9   ENTRIES    int64
#  10  EXITS      int64
#  11  TIMESTAMP  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(9)
# memory usage: 342.6+ MB

# %%
df['WEEKDAYS'] = pd.to_datetime(df['DATE']).dt.day_name()
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  16:00:00
#
#       DESC  ENTRIES    EXITS           TIMESTAMP  WEEKDAYS
# 0  REGULAR  7415454  2518022 2020-04-25 00:00:00  Saturday
# 1  REGULAR  7415454  2518022 2020-04-25 04:00:00  Saturday
# 2  REGULAR  7415459  2518033 2020-04-25 08:00:00  Saturday
# 3  REGULAR  7415468  2518044 2020-04-25 12:00:00  Saturday
# 4  REGULAR  7415480  2518056 2020-04-25 16:00:00  Saturday

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3741614 entries, 0 to 3741613
# Data columns (total 13 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   C/A        object
#  1   UNIT       object
#  2   SCP        object
#  3   STATION    object
#  4   LINENAME   object
#  5   DIVISION   object
#  6   DATE       object
#  7   TIME       object
#  8   DESC       object
#  9   ENTRIES    int64
#  10  EXITS      int64
#  11  TIMESTAMP  datetime64[ns]
#  12  WEEKDAYS   object
# dtypes: datetime64[ns](1), int64(2), object(10)
# memory usage: 371.1+ MB

# %%
df["TURNSTILE"] = df["C/A"]+"-"+df["UNIT"]+"-"+df["SCP"]

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS', 'TIMESTAMP', 'WEEKDAYS', 'TURNSTILE'],
#       dtype='object')

# %%
df.head(5)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  16:00:00
#
#       DESC  ENTRIES    EXITS           TIMESTAMP  WEEKDAYS           TURNSTILE
# 0  REGULAR  7415454  2518022 2020-04-25 00:00:00  Saturday  A002-R051-02-00-00
# 1  REGULAR  7415454  2518022 2020-04-25 04:00:00  Saturday  A002-R051-02-00-00
# 2  REGULAR  7415459  2518033 2020-04-25 08:00:00  Saturday  A002-R051-02-00-00
# 3  REGULAR  7415468  2518044 2020-04-25 12:00:00  Saturday  A002-R051-02-00-00
# 4  REGULAR  7415480  2518056 2020-04-25 16:00:00  Saturday  A002-R051-02-00-00

# %%
df.shape
# Out:
# (3741614, 14)

# %% [markdown]
# #Duplicate var ise sil

# %%
df.drop_duplicates(subset=None, keep="first", inplace=True)

# %%
df.shape
# Out:
# (3741614, 14)

# %%
df.describe()
# Out:
#             ENTRIES         EXITS
# count  3.741614e+06  3.741614e+06
# mean   4.299895e+07  3.519881e+07
# std    2.188519e+08  1.988566e+08
# min    0.000000e+00  0.000000e+00
# 25%    2.947392e+05  1.287430e+05
# 50%    1.838160e+06  1.064599e+06
# 75%    6.484410e+06  4.381205e+06
# max    2.128763e+09  2.123298e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3741614 entries, 0 to 3741613
# Data columns (total 14 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   C/A        object
#  1   UNIT       object
#  2   SCP        object
#  3   STATION    object
#  4   LINENAME   object
#  5   DIVISION   object
#  6   DATE       object
#  7   TIME       object
#  8   DESC       object
#  9   ENTRIES    int64
#  10  EXITS      int64
#  11  TIMESTAMP  datetime64[ns]
#  12  WEEKDAYS   object
#  13  TURNSTILE  object
# dtypes: datetime64[ns](1), int64(2), object(11)
# memory usage: 428.2+ MB

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/25/2020  16:00:00
#
#       DESC  ENTRIES    EXITS           TIMESTAMP  WEEKDAYS           TURNSTILE
# 0  REGULAR  7415454  2518022 2020-04-25 00:00:00  Saturday  A002-R051-02-00-00
# 1  REGULAR  7415454  2518022 2020-04-25 04:00:00  Saturday  A002-R051-02-00-00
# 2  REGULAR  7415459  2518033 2020-04-25 08:00:00  Saturday  A002-R051-02-00-00
# 3  REGULAR  7415468  2518044 2020-04-25 12:00:00  Saturday  A002-R051-02-00-00
# 4  REGULAR  7415480  2518056 2020-04-25 16:00:00  Saturday  A002-R051-02-00-00

# %%
df = df[["STATION","TURNSTILE","DATE","TIME", "TIMESTAMP","ENTRIES","EXITS", "WEEKDAYS"]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3741614 entries, 0 to 3741613
# Data columns (total 8 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   STATION    object
#  1   TURNSTILE  object
#  2   DATE       object
#  3   TIME       object
#  4   TIMESTAMP  datetime64[ns]
#  5   ENTRIES    int64
#  6   EXITS      int64
#  7   WEEKDAYS   object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 256.9+ MB

# %%
print("Maximum date: ")
print(df["TIMESTAMP"].max())
print()
print("Minimum date: ")
print(df["TIMESTAMP"].min())
# Out:
# Maximum date:
# 2020-08-28 23:59:47
#
# Minimum date:
# 2020-04-25 00:00:00

# %%
len(df["STATION"].unique())
# Out:
# 379

# %%
len(df["TURNSTILE"].unique())
# Out:
# 4993

# %%
print("Row count based on stations (First 10 rows)")
print(df["STATION"].value_counts().sort_values(ascending=False).head(10))
# Out:
# Row count based on stations (First 10 rows)
# 34 ST-PENN STA     75160
# FULTON ST          73637
# GRD CNTRL-42 ST    56389
# 23 ST              55133
# 86 ST              48059
# CANAL ST           43894
# CHAMBERS ST        41472
# 34 ST-HERALD SQ    40599
# 14 ST              38589
# 42 ST-PORT AUTH    38282
# Name: STATION, dtype: int64

# %%
df['NET_ENTRIES'] = df.ENTRIES.shift(-1) - df.ENTRIES
df['NET_EXITS'] = df.EXITS.shift(-1) - df.EXITS

# %%
df.head(50)
# Out:
#    STATION           TURNSTILE        DATE      TIME           TIMESTAMP  \
# 0    59 ST  A002-R051-02-00-00  04/25/2020  00:00:00 2020-04-25 00:00:00
# 1    59 ST  A002-R051-02-00-00  04/25/2020  04:00:00 2020-04-25 04:00:00
# 2    59 ST  A002-R051-02-00-00  04/25/2020  08:00:00 2020-04-25 08:00:00
# 3    59 ST  A002-R051-02-00-00  04/25/2020  12:00:00 2020-04-25 12:00:00
# 4    59 ST  A002-R051-02-00-00  04/25/2020  16:00:00 2020-04-25 16:00:00
# 5    59 ST  A002-R051-02-00-00  04/25/2020  20:00:00 2020-04-25 20:00:00
# 6    59 ST  A002-R051-02-00-00  04/26/2020  00:00:00 2020-04-26 00:00:00
# 7    59 ST  A002-R051-02-00-00  04/26/2020  04:00:00 2020-04-26 04:00:00
# 8    59 ST  A002-R051-02-00-00  04/26/2020  08:00:00 2020-04-26 08:00:00
# 9    59 ST  A002-R051-02-00-00  04/26/2020  12:00:00 2020-04-26 12:00:00
# 10   59 ST  A002-R051-02-00-00  04/26/2020  16:00:00 2020-04-26 16:00:00
# 11   59 ST  A002-R051-02-00-00  04/26/2020  20:00:00 2020-04-26 20:00:00
# 12   59 ST  A002-R051-02-00-00  04/27/2020  00:00:00 2020-04-27 00:00:00
# 48  6591289  1484105     Sunday          2.0        0.0
# 49  6591291  1484105     Sunday          4.0        7.0

# %% [markdown]
# #Veriyi anlayabilmek için tanımlayacak istatistiklerine bakalım

# %%
print("Descriptive Statistics for NET_ENTRIES column:") 
print(df["NET_ENTRIES"].describe())
print("Descriptive Statistics for NET_EXITS column:")
print(df["NET_EXITS"].describe())
# Out:
# Descriptive Statistics for NET_ENTRIES column:
# count    3.741613e+06
# mean    -1.980403e+00
# std      4.549120e+07
# min     -2.128662e+09
# 25%      0.000000e+00
# 50%      9.000000e+00
# 75%      3.800000e+01
# max      2.120110e+09
# Name: NET_ENTRIES, dtype: float64
# Descriptive Statistics for NET_EXITS column:
# count    3.741613e+06
# mean    -6.728333e-01
# std      4.182783e+07
# min     -2.109524e+09
# 25%      1.000000e+00
# 50%      1.100000e+01
# 75%      3.700000e+01
# max      2.123296e+09
# Name: NET_EXITS, dtype: float64

# %%
pd.options.display.float_format='{:.5f}'.format

# %%
df.describe()
# Out:
#                ENTRIES            EXITS       NET_ENTRIES         NET_EXITS
# count    3741614.00000    3741614.00000     3741613.00000     3741613.00000
# mean    42998947.39363   35198813.02059          -1.98040          -0.67283
# std    218851927.30337  198856573.69932    45491199.54700    41827834.62899
# min            0.00000          0.00000 -2128661952.00000 -2109523662.00000
# 25%       294739.25000     128743.00000           0.00000           1.00000
# 50%      1838160.50000    1064599.00000           9.00000          11.00000
# 75%      6484410.50000    4381204.75000          38.00000          37.00000
# max   2128762902.00000 2123298383.00000  2120109987.00000  2123296408.00000

# %%
df.columns
# Out:
# Index(['STATION', 'TURNSTILE', 'DATE', 'TIME', 'TIMESTAMP', 'ENTRIES', 'EXITS',
#        'WEEKDAYS', 'NET_ENTRIES', 'NET_EXITS'],
#       dtype='object')

# %%
df.shape
# Out:
# (3741614, 10)

# %% [markdown]
# #Negatif değerler NET_ENTRIES ve NET_EXITSte kaç tane var

# %%
print("Negative values for NET_ENTRIES column: ")
print(len(df[df["NET_ENTRIES"]<0]))
print("Negative values for NET_EXITS column:")
print(len(df[df["NET_EXITS"]<0]))
# Out:
# Negative values for NET_ENTRIES column:
# 72800
# Negative values for NET_EXITS column:
# 66840

# %% [markdown]
# #Boş olanlara 0 atadık. Negatif ve de %95 güven aralığının üstünde olan değerlere median değerlerini atadık

# %%
df['NET_ENTRIES'][df['NET_ENTRIES'] < 0] = (df["NET_ENTRIES"].median())
df['NET_EXITS'][df['NET_EXITS'] < 0] = (df["NET_EXITS"].median())
df['NET_ENTRIES'][df['NET_ENTRIES'] > (df["NET_ENTRIES"].quantile(0.95))] = (df["NET_ENTRIES"].median()) 
df['NET_EXITS'][df['NET_EXITS'] > (df["NET_EXITS"].quantile(0.95))] = (df["NET_EXITS"].median())
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_6040/3552351569.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NET_ENTRIES'][df['NET_ENTRIES'] < 0] = (df["NET_ENTRIES"].median())
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_6040/3552351569.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NET_EXITS'][df['NET_EXITS'] < 0] = (df["NET_EXITS"].median())
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_6040/3552351569.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NET_ENTRIES'][df['NET_ENTRIES'] > (df["NET_ENTRIES"].quantile(0.95))] = (df["NET_ENTRIES"].median())
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_6040/3552351569.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NET_EXITS'][df['NET_EXITS'] > (df["NET_EXITS"].quantile(0.95))] = (df["NET_EXITS"].median())

# %%
pd.options.display.float_format='{:.5f}'.format

# %%
print("Descriptive Statistics for NET_ENTRIES column:")
print(df["NET_ENTRIES"].describe())
print("Descriptive Statistics for NET_EXITS column:")
print(df["NET_EXITS"].describe())
# Out:
# Descriptive Statistics for NET_ENTRIES column:
# count   3741613.00000
# mean         21.13144
# std          29.42956
# min           0.00000
# 25%           1.00000
# 50%           9.00000
# 75%          29.00000
# max         141.00000
# Name: NET_ENTRIES, dtype: float64
# Descriptive Statistics for NET_EXITS column:
# count   3741613.00000
# mean         21.81962
# std          29.42629
# min           0.00000
# 25%           2.00000
# 50%          11.00000
# 75%          29.00000
# max         146.00000
# Name: NET_EXITS, dtype: float64

# %%
df["TRAFFIC"] = df["NET_ENTRIES"] + df["NET_EXITS"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3741614 entries, 0 to 3741613
# Data columns (total 11 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   STATION      object
#  1   TURNSTILE    object
#  2   DATE         object
#  3   TIME         object
#  4   TIMESTAMP    datetime64[ns]
#  5   ENTRIES      int64
#  6   EXITS        int64
#  7   WEEKDAYS     object
#  8   NET_ENTRIES  float64
#  9   NET_EXITS    float64
#  10  TRAFFIC      float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(5)
# memory usage: 342.6+ MB

# %%
df.head(50)
# Out:
#    STATION           TURNSTILE        DATE      TIME           TIMESTAMP  \
# 0    59 ST  A002-R051-02-00-00  04/25/2020  00:00:00 2020-04-25 00:00:00
# 1    59 ST  A002-R051-02-00-00  04/25/2020  04:00:00 2020-04-25 04:00:00
# 2    59 ST  A002-R051-02-00-00  04/25/2020  08:00:00 2020-04-25 08:00:00
# 3    59 ST  A002-R051-02-00-00  04/25/2020  12:00:00 2020-04-25 12:00:00
# 4    59 ST  A002-R051-02-00-00  04/25/2020  16:00:00 2020-04-25 16:00:00
# 5    59 ST  A002-R051-02-00-00  04/25/2020  20:00:00 2020-04-25 20:00:00
# 6    59 ST  A002-R051-02-00-00  04/26/2020  00:00:00 2020-04-26 00:00:00
# 7    59 ST  A002-R051-02-00-00  04/26/2020  04:00:00 2020-04-26 04:00:00
# 8    59 ST  A002-R051-02-00-00  04/26/2020  08:00:00 2020-04-26 08:00:00
# 9    59 ST  A002-R051-02-00-00  04/26/2020  12:00:00 2020-04-26 12:00:00
# 10   59 ST  A002-R051-02-00-00  04/26/2020  16:00:00 2020-04-26 16:00:00
# 11   59 ST  A002-R051-02-00-00  04/26/2020  20:00:00 2020-04-26 20:00:00
# 12   59 ST  A002-R051-02-00-00  04/27/2020  00:00:00 2020-04-27 00:00:00
# 13   59 ST  A002-R051-02-00-00  04/27/2020  04:00:00 2020-04-27 04:00:00
# 14   59 ST  A002-R051-02-00-00  04/27/2020  08:00:00 2020-04-27 08:00:00
# 15   59 ST  A002-R051-02-00-00  04/27/2020  12:00:00 2020-04-27 12:00:00
# 43  6591232  1484081   Saturday      4.00000    5.00000  9.00000
# 44  6591236  1484086   Saturday      3.00000    4.00000  7.00000
# 45  6591239  1484090   Saturday     21.00000    6.00000 27.00000
# 46  6591260  1484096   Saturday     19.00000    4.00000 23.00000
# 47  6591279  1484100   Saturday     10.00000    5.00000 15.00000
# 48  6591289  1484105     Sunday      2.00000    0.00000  2.00000
# 49  6591291  1484105     Sunday      4.00000    7.00000 11.00000

# %%
df.TRAFFIC.describe()
# Out:
# count   3741613.00000
# mean         42.95105
# std          49.39445
# min           0.00000
# 25%           4.00000
# 50%          23.00000
# 75%          66.00000
# max         287.00000
# Name: TRAFFIC, dtype: float64

# %%
df.TRAFFIC.value_counts()
# Out:
# 0.00000      602699
# 20.00000     163808
# 1.00000      111716
# 2.00000       93271
# 3.00000       82450
#               ...
# 284.00000        25
# 282.00000        21
# 286.00000        10
# 285.00000         7
# 287.00000         4
# Name: TRAFFIC, Length: 288, dtype: int64

# %%
df['WEEKDAYS_INDEX'] = pd.to_datetime(df['DATE']).dt.weekday
df.head()
# Out:
#   STATION           TURNSTILE        DATE      TIME           TIMESTAMP  \
# 0   59 ST  A002-R051-02-00-00  04/25/2020  00:00:00 2020-04-25 00:00:00
# 1   59 ST  A002-R051-02-00-00  04/25/2020  04:00:00 2020-04-25 04:00:00
# 2   59 ST  A002-R051-02-00-00  04/25/2020  08:00:00 2020-04-25 08:00:00
# 3   59 ST  A002-R051-02-00-00  04/25/2020  12:00:00 2020-04-25 12:00:00
# 4   59 ST  A002-R051-02-00-00  04/25/2020  16:00:00 2020-04-25 16:00:00
#
#    ENTRIES    EXITS  WEEKDAYS  NET_ENTRIES  NET_EXITS  TRAFFIC  WEEKDAYS_INDEX
# 0  7415454  2518022  Saturday      0.00000    0.00000  0.00000               5
# 1  7415454  2518022  Saturday      5.00000   11.00000 16.00000               5
# 2  7415459  2518033  Saturday      9.00000   11.00000 20.00000               5
# 3  7415468  2518044  Saturday     12.00000   12.00000 24.00000               5
# 4  7415480  2518056  Saturday     20.00000    8.00000 28.00000               5

# %%
busiest_stations = df.groupby("STATION").sum().sort_values("TRAFFIC", ascending = False).reset_index().head(10)
busiest_stations.head(10)
# Out:
#            STATION        ENTRIES          EXITS   NET_ENTRIES     NET_EXITS  \
# 0   34 ST-PENN STA  3674799416722  3909197532070 1663977.00000 1876951.00000
# 1           125 ST  4574614145805  2894763928164 1196975.00000 1336577.00000
# 2            86 ST  1055091100573  1716807566862 1163395.00000 1196766.00000
# 3        FULTON ST  3690075524363  3598268033656 1107362.00000 1223303.00000
# 4            23 ST  4354286049141  4382121866864 1103627.00000 1192754.00000
# 5  34 ST-HERALD SQ  3382544541715  4340567295518  932997.00000 1196328.00000
# 6   TIMES SQ-42 ST  3312348128690  2672519277963  824005.00000 1064950.00000
# 7            96 ST   699900859427   137051457977  807454.00000  998864.00000
# 8   14 ST-UNION SQ   215628670310   146826471870  774753.00000  953135.00000
# 9            59 ST  1059226894792   706548682325  769672.00000  945764.00000
#
#         TRAFFIC  WEEKDAYS_INDEX
# 0 3540928.00000          225102
# 1 2533552.00000           97192
# 2 2360161.00000          144059
# 3 2330665.00000          218555
# 4 2296381.00000          165291
# 5 2129325.00000          121814
# 6 1888955.00000          100645
# 7 1806318.00000           83416
# 8 1727888.00000           93372
# 9 1715436.00000          106522

# %%
plt.figure(figsize=(10,6),dpi=200)
plt.bar(busiest_stations.STATION, busiest_stations.TRAFFIC)
plt.xticks(rotation=45, ha='right');
plt.xlabel("STATIONS")
plt.ylabel("TOTAL TRAFFIC")
plt.title("TOP 10 BUSIEST STATIONS 2020", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOP 10 BUSIEST STATIONS 2020')

# %%
plt.figure(figsize=(10,6),dpi=200)
plt.barh(busiest_stations.STATION, busiest_stations.TRAFFIC, color=['blue', 'orange', 'orange', 'orange', 'orange','orange','orange','orange','orange','orange']);
plt.gca().invert_yaxis()
plt.xlabel("TOTAL TRAFFIC")
plt.ylabel(" ")
plt.title("TOP 10 BUSIEST STATIONS 2020", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOP 10 BUSIEST STATIONS 2020')

# %%
plt.figure(figsize=(10,6),dpi=200)
sns.set_style("whitegrid")
sns.barplot(y = 'STATION', x = 'TRAFFIC', data = busiest_stations)
plt.xlabel("TOTAL TRAFFIC")
plt.ylabel(" ")
plt.title("TOP 10 BUSIEST STATIONS 2020", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOP 10 BUSIEST STATIONS 2020')

# %%
busiest_days = df.groupby("WEEKDAYS").sum().sort_values("WEEKDAYS_INDEX", ascending = True).reset_index()
busiest_days
# Out:
#     WEEKDAYS         ENTRIES           EXITS    NET_ENTRIES      NET_EXITS  \
# 0     Monday  22909634233267  18795229741985 12198044.00000 12400818.00000
# 1    Tuesday  22927169236328  18810124176193 12479955.00000 12668138.00000
# 2  Wednesday  23006298213050  18838741746332 12584313.00000 12781277.00000
# 3   Thursday  23030627137817  18838004331661 12626699.00000 12845181.00000
# 4     Friday  22837092074833  18736632266961 12021728.00000 12181776.00000
# 5   Saturday  23366748586778  18943337320256  9322551.00000 10006235.00000
# 6     Sunday  22807894071195  18738301997836  7832369.00000  8757135.00000
#
#          TRAFFIC  WEEKDAYS_INDEX
# 0 24598862.00000               0
# 1 25148093.00000          532726
# 2 25365590.00000         1067062
# 3 25471880.00000         1598973
# 4 24203504.00000         2131100
# 5 19328786.00000         2724380
# 6 16589504.00000         3191406

# %%
plt.figure(figsize=(10,6),dpi=200)
plt.bar(busiest_days.WEEKDAYS, busiest_days.TRAFFIC, color=['red' if x < 50000000 else 'blue' for x in busiest_days.TRAFFIC.values]);
plt.xlabel(" ")
plt.ylabel("TOTAL TRAFFIC")
plt.title("TOTAL TRAFFIC ACCORDING TO WEEKDAYS 2020", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOTAL TRAFFIC ACCORDING TO WEEKDAYS 2020')

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.set_style("whitegrid")
sns.barplot(x = 'WEEKDAYS', y = 'TRAFFIC', data = busiest_days)
plt.ylabel("TOTAL TRAFFIC")
plt.xlabel(" ")
plt.title("TOTAL TRAFFIC ACCORDING TO WEEKDAYS 2020", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOTAL TRAFFIC ACCORDING TO WEEKDAYS 2020')

# %%
busiest_times = df.groupby("TIME").sum().sort_values("TRAFFIC", ascending = False).reset_index()

# %%
for i in range(len(busiest_times)):
    
    if busiest_times['TIME'][i] < ('04:00:00'):
        busiest_times['TIME'][i] =  ('00:00 - 04:00')
    
    elif ('04:00:00') <= busiest_times['TIME'][i] < ('08:00:00'):
        busiest_times['TIME'][i] =  ('04:00 - 08:00')
    
    elif ('08:00:00') <= busiest_times['TIME'][i] < ('12:00:00'):
        busiest_times['TIME'][i] =  ('08:00 - 12:00')
    
    elif ('12:00:00') <= busiest_times['TIME'][i] < ('16:00:00'):
        busiest_times['TIME'][i] =  ('12:00 - 16:00')
    
    elif ('16:00:00') <= busiest_times['TIME'][i] < ('20:00:00'):
        busiest_times['TIME'][i] =  ('16:00 - 20:00')
    
    elif ('20:00:00') <= busiest_times['TIME'][i]:
        busiest_times['TIME'][i] =  ('20:00 - 00:00')
        
    i = i + 1
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_6040/3535484847.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   busiest_times['TIME'][i] =  ('12:00 - 16:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_6040/3535484847.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   busiest_times['TIME'][i] =  ('16:00 - 20:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_6040/3535484847.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   busiest_times['TIME'][i] =  ('08:00 - 12:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_6040/3535484847.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   busiest_times['TIME'][i] =  ('04:00 - 08:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_6040/3535484847.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   busiest_times['TIME'][i] =  ('20:00 - 00:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_6040/3535484847.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   busiest_times['TIME'][i] =  ('00:00 - 04:00')

# %%
busiest_times
# Out:
#                 TIME         ENTRIES           EXITS    NET_ENTRIES  \
# 0      12:00 - 16:00  15480549524888  13295338699588 11065347.00000
# 1      16:00 - 20:00  15485829626711  13296636714787 10823607.00000
# 2      08:00 - 12:00  15482564773686  13299540183147  8650341.00000
# 3      12:00 - 16:00   9323306608442   6945018063137  8038905.00000
# 4      04:00 - 08:00  15494016619997  13311270800693  6773865.00000
# ...              ...             ...             ...            ...
# 60417  00:00 - 04:00            3672           33140        0.00000
# 60418  16:00 - 20:00          151942           71389        0.00000
# 60419  20:00 - 00:00           97970           33454        0.00000
# 60420  00:00 - 04:00          352543           37661        0.00000
# 60421  04:00 - 08:00              84              74        0.00000
#
#            NET_EXITS        TRAFFIC  WEEKDAYS_INDEX
# 0     10065462.00000 21130809.00000          951245
# 1      9485266.00000 20308873.00000          951366
# 2      9491582.00000 18141923.00000          951359
# 3      7582948.00000 15621853.00000          700415
# 4      7146454.00000 13920319.00000          952332
# ...              ...            ...             ...
# 60417        0.00000        0.00000               2
# 60418        0.00000        0.00000              10
# 60419        0.00000        0.00000               0
# 60420        0.00000        0.00000               0
# 60421        0.00000        0.00000               8
#
# [60422 rows x 7 columns]

# %%
busiest_times = busiest_times.groupby("TIME").sum().sort_values("TRAFFIC", ascending = False).reset_index()
busiest_times
# Out:
#             TIME         ENTRIES           EXITS    NET_ENTRIES  \
# 0  12:00 - 16:00  26838674450051  21953267777775 20745827.00000
# 1  16:00 - 20:00  26728270612486  21901229629266 18664364.00000
# 2  08:00 - 12:00  26899013653047  22032051025273 16228614.00000
# 3  04:00 - 08:00  27122363964316  22097169333050 13871075.00000
# 4  20:00 - 00:00  26671833691835  21881752888851  8444108.00000
# 5  00:00 - 04:00  26625307181533  21834900927009  1111671.00000
#
#        NET_EXITS        TRAFFIC  WEEKDAYS_INDEX
# 0 19188399.00000 39934226.00000         1870992
# 1 17361359.00000 36025723.00000         1863644
# 2 17288705.00000 33517319.00000         1881660
# 3 14691431.00000 28562506.00000         1911022
# 4 10500504.00000 18944612.00000         1856392
# 5  2610162.00000  3721833.00000         1861937

# %%
plt.figure(figsize=(10,6),dpi=200)
sns.set_style("whitegrid")

# %%
sns.barplot(x = 'TIME', y = 'TRAFFIC', data = busiest_times, order = ['00:00 - 04:00', '04:00 - 08:00', '08:00 - 12:00', '12:00 - 16:00', '16:00 - 20:00', '20:00 - 00:00'])
plt.xlabel(" ")
plt.ylabel("TOTAL TRAFFIC")
plt.title("TOTAL TRAFFIC ACCORDING TO TIMES OF DAY 2020", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOTAL TRAFFIC ACCORDING TO TIMES OF DAY 2020')

# %%
busiest_stations_weekdays = df.groupby(['STATION','WEEKDAYS',"WEEKDAYS_INDEX"]).agg({'TRAFFIC':'sum'}).reset_index()[["STATION","WEEKDAYS","TRAFFIC","WEEKDAYS_INDEX"]]
busiest_stations_weekdays
# Out:
#         STATION   WEEKDAYS      TRAFFIC  WEEKDAYS_INDEX
# 0          1 AV     Friday 102327.00000               4
# 1          1 AV     Monday 104369.00000               0
# 2          1 AV   Saturday  84375.00000               5
# 3          1 AV     Sunday  71624.00000               6
# 4          1 AV   Thursday 111795.00000               3
# ...         ...        ...          ...             ...
# 2648  ZEREGA AV   Saturday  15202.00000               5
# 2649  ZEREGA AV     Sunday  12258.00000               6
# 2650  ZEREGA AV   Thursday  21064.00000               3
# 2651  ZEREGA AV    Tuesday  20730.00000               1
# 2652  ZEREGA AV  Wednesday  20833.00000               2
#
# [2653 rows x 4 columns]

# %%
station1 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "34 ST-PENN STA" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station1
# Out:
#             STATION   WEEKDAYS      TRAFFIC  WEEKDAYS_INDEX
# 428  34 ST-PENN STA     Monday 554768.00000               0
# 432  34 ST-PENN STA    Tuesday 568257.00000               1
# 433  34 ST-PENN STA  Wednesday 569198.00000               2
# 431  34 ST-PENN STA   Thursday 574725.00000               3
# 427  34 ST-PENN STA     Friday 547353.00000               4
# 429  34 ST-PENN STA   Saturday 387635.00000               5
# 430  34 ST-PENN STA     Sunday 338992.00000               6

# %%
station2 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "125 ST" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station2
# Out:
#    STATION   WEEKDAYS      TRAFFIC  WEEKDAYS_INDEX
# 64  125 ST     Monday 375583.00000               0
# 68  125 ST    Tuesday 377434.00000               1
# 69  125 ST  Wednesday 379344.00000               2
# 67  125 ST   Thursday 379455.00000               3
# 63  125 ST     Friday 329914.00000               4
# 65  125 ST   Saturday 364387.00000               5
# 66  125 ST     Sunday 327435.00000               6

# %%
station3 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "86 ST" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station3
# Out:
#     STATION   WEEKDAYS      TRAFFIC  WEEKDAYS_INDEX
# 771   86 ST     Monday 359264.00000               0
# 775   86 ST    Tuesday 369795.00000               1
# 776   86 ST  Wednesday 369913.00000               2
# 774   86 ST   Thursday 372435.00000               3
# 770   86 ST     Friday 344543.00000               4
# 772   86 ST   Saturday 295494.00000               5
# 773   86 ST     Sunday 248717.00000               6

# %%
station4 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "FULTON ST" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station4
# Out:
#         STATION   WEEKDAYS      TRAFFIC  WEEKDAYS_INDEX
# 1583  FULTON ST     Monday 370157.00000               0
# 1587  FULTON ST    Tuesday 378338.00000               1
# 1588  FULTON ST  Wednesday 381992.00000               2
# 1586  FULTON ST   Thursday 387951.00000               3
# 1582  FULTON ST     Friday 390242.00000               4
# 1584  FULTON ST   Saturday 233580.00000               5
# 1585  FULTON ST     Sunday 188405.00000               6

# %%
station5 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "23 ST" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station5
# Out:
#     STATION   WEEKDAYS      TRAFFIC  WEEKDAYS_INDEX
# 323   23 ST     Monday 357872.00000               0
# 327   23 ST    Tuesday 367504.00000               1
# 328   23 ST  Wednesday 377745.00000               2
# 326   23 ST   Thursday 378162.00000               3
# 322   23 ST     Friday 362928.00000               4
# 324   23 ST   Saturday 251306.00000               5
# 325   23 ST     Sunday 200864.00000               6

# %%
station6 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "34 ST-HERALD SQ" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station6
# Out:
#              STATION   WEEKDAYS      TRAFFIC  WEEKDAYS_INDEX
# 414  34 ST-HERALD SQ     Monday 326857.00000               0
# 418  34 ST-HERALD SQ    Tuesday 334015.00000               1
# 419  34 ST-HERALD SQ  Wednesday 335768.00000               2
# 417  34 ST-HERALD SQ   Thursday 339352.00000               3
# 413  34 ST-HERALD SQ     Friday 310775.00000               4
# 415  34 ST-HERALD SQ   Saturday 259188.00000               5
# 416  34 ST-HERALD SQ     Sunday 223370.00000               6

# %%
station7 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "TIMES SQ-42 ST" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station7
# Out:
#              STATION   WEEKDAYS      TRAFFIC  WEEKDAYS_INDEX
# 2472  TIMES SQ-42 ST     Monday 295071.00000               0
# 2476  TIMES SQ-42 ST    Tuesday 300929.00000               1
# 2477  TIMES SQ-42 ST  Wednesday 307215.00000               2
# 2475  TIMES SQ-42 ST   Thursday 307229.00000               3
# 2471  TIMES SQ-42 ST     Friday 283271.00000               4
# 2473  TIMES SQ-42 ST   Saturday 214280.00000               5
# 2474  TIMES SQ-42 ST     Sunday 180960.00000               6

# %%
station8 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "96 ST" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station8
# Out:
#     STATION   WEEKDAYS      TRAFFIC  WEEKDAYS_INDEX
# 806   96 ST     Monday 276481.00000               0
# 810   96 ST    Tuesday 280209.00000               1
# 811   96 ST  Wednesday 281220.00000               2
# 809   96 ST   Thursday 283077.00000               3
# 805   96 ST     Friday 259671.00000               4
# 807   96 ST   Saturday 226285.00000               5
# 808   96 ST     Sunday 199375.00000               6

# %%
station9 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "14 ST-UNION SQ" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station9
# Out:
#             STATION   WEEKDAYS      TRAFFIC  WEEKDAYS_INDEX
# 99   14 ST-UNION SQ     Monday 252173.00000               0
# 103  14 ST-UNION SQ    Tuesday 263825.00000               1
# 104  14 ST-UNION SQ  Wednesday 271744.00000               2
# 102  14 ST-UNION SQ   Thursday 270274.00000               3
# 98   14 ST-UNION SQ     Friday 244341.00000               4
# 100  14 ST-UNION SQ   Saturday 226988.00000               5
# 101  14 ST-UNION SQ     Sunday 198543.00000               6

# %%
station10 = busiest_stations_weekdays[ busiest_stations_weekdays.loc[: , "STATION"] == "59 ST" ].sort_values("WEEKDAYS_INDEX",ascending = True)
station10
# Out:
#     STATION   WEEKDAYS      TRAFFIC  WEEKDAYS_INDEX
# 596   59 ST     Monday 265063.00000               0
# 600   59 ST    Tuesday 272236.00000               1
# 601   59 ST  Wednesday 272295.00000               2
# 599   59 ST   Thursday 271108.00000               3
# 595   59 ST     Friday 250349.00000               4
# 597   59 ST   Saturday 212130.00000               5
# 598   59 ST     Sunday 172255.00000               6

# %%
stations = [station1, station2, station3 ,station4 ,station5]
stations_for_tourists = pd.concat(stations)
stations_for_tourists
# Out:
#              STATION   WEEKDAYS      TRAFFIC  WEEKDAYS_INDEX
# 428   34 ST-PENN STA     Monday 554768.00000               0
# 432   34 ST-PENN STA    Tuesday 568257.00000               1
# 433   34 ST-PENN STA  Wednesday 569198.00000               2
# 431   34 ST-PENN STA   Thursday 574725.00000               3
# 427   34 ST-PENN STA     Friday 547353.00000               4
# 429   34 ST-PENN STA   Saturday 387635.00000               5
# 430   34 ST-PENN STA     Sunday 338992.00000               6
# 64            125 ST     Monday 375583.00000               0
# 68            125 ST    Tuesday 377434.00000               1
# 69            125 ST  Wednesday 379344.00000               2
# 67            125 ST   Thursday 379455.00000               3
# 63            125 ST     Friday 329914.00000               4
# 65            125 ST   Saturday 364387.00000               5
# 66            125 ST     Sunday 327435.00000               6
# 771            86 ST     Monday 359264.00000               0
# 775            86 ST    Tuesday 369795.00000               1
# 776            86 ST  Wednesday 369913.00000               2
# 774            86 ST   Thursday 372435.00000               3
# 770            86 ST     Friday 344543.00000               4
# 772            86 ST   Saturday 295494.00000               5
# 773            86 ST     Sunday 248717.00000               6
# 1583       FULTON ST     Monday 370157.00000               0
# 1587       FULTON ST    Tuesday 378338.00000               1
# 1588       FULTON ST  Wednesday 381992.00000               2
# 1586       FULTON ST   Thursday 387951.00000               3
# 1582       FULTON ST     Friday 390242.00000               4
# 1584       FULTON ST   Saturday 233580.00000               5
# 1585       FULTON ST     Sunday 188405.00000               6
# 323            23 ST     Monday 357872.00000               0
# 327            23 ST    Tuesday 367504.00000               1
# 328            23 ST  Wednesday 377745.00000               2
# 326            23 ST   Thursday 378162.00000               3
# 322            23 ST     Friday 362928.00000               4
# 324            23 ST   Saturday 251306.00000               5
# 325            23 ST     Sunday 200864.00000               6

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.lineplot(data=stations_for_tourists, x="WEEKDAYS", y="TRAFFIC", hue="STATION")
ax.axvspan("Wednesday", "Thursday", alpha=0.15, color='blue')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.title("TOTAL TRAFFIC OF TOP 5 STATIONS BY WEEKDAYS 2019", family='serif',fontsize = 15,loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'TOTAL TRAFFIC OF TOP 5 STATIONS BY WEEKDAYS 2019')

# %%
Most_Busiest_Station = df[df['STATION'] == '34 ST-PENN STA']
Most_Busiest_Station
# Out:
#                 STATION           TURNSTILE        DATE      TIME  \
# 53864    34 ST-PENN STA  N067-R012-00-00-00  04/25/2020  00:00:00
# 53865    34 ST-PENN STA  N067-R012-00-00-00  04/25/2020  04:00:00
# 53866    34 ST-PENN STA  N067-R012-00-00-00  04/25/2020  08:00:00
# 53867    34 ST-PENN STA  N067-R012-00-00-00  04/25/2020  12:00:00
# 53868    34 ST-PENN STA  N067-R012-00-00-00  04/25/2020  16:00:00
# ...                 ...                 ...         ...       ...
# 3672475  34 ST-PENN STA  R142-R293-01-06-01  08/28/2020  06:00:00
# 3672476  34 ST-PENN STA  R142-R293-01-06-01  08/28/2020  10:00:00
# 3672477  34 ST-PENN STA  R142-R293-01-06-01  08/28/2020  14:00:00
# 3672478  34 ST-PENN STA  R142-R293-01-06-01  08/28/2020  18:00:00
# 3672479  34 ST-PENN STA  R142-R293-01-06-01  08/28/2020  22:00:00
#
#                   TIMESTAMP   ENTRIES     EXITS  WEEKDAYS  NET_ENTRIES  \
# 53864   2020-04-25 00:00:00    198195    594376  Saturday      0.00000
# 53865   2020-04-25 04:00:00    198195    594380  Saturday      1.00000
# 53866   2020-04-25 08:00:00    198196    594384  Saturday      0.00000
# 53867   2020-04-25 12:00:00    198196    594389  Saturday      2.00000
# 53868   2020-04-25 16:00:00    198198    594396  Saturday      1.00000
# ...                     ...       ...       ...       ...          ...
# 3672475 2020-08-28 06:00:00  68045757  18700963    Friday      6.00000
# 3672476 2020-08-28 10:00:00  68045763  18701017    Friday     27.00000
# 3672477 2020-08-28 14:00:00  68045790  18701068    Friday     44.00000
# 3672478 2020-08-28 18:00:00  68045834  18701105    Friday     18.00000
# 3672479 2020-08-28 22:00:00  68045852  18701142    Friday      9.00000
#
#          NET_EXITS  TRAFFIC  WEEKDAYS_INDEX
# 53864      4.00000  4.00000               5
# 53865      4.00000  5.00000               5
# 53866      5.00000  5.00000               5
# 53867      7.00000  9.00000               5
# 53868      1.00000  2.00000               5
# ...            ...      ...             ...
# 3672475   54.00000 60.00000               4
# 3672476   51.00000 78.00000               4
# 3672477   37.00000 81.00000               4
# 3672478   37.00000 55.00000               4
# 3672479   11.00000 20.00000               4
#
# [75160 rows x 12 columns]

# %%
for i in range(len(Most_Busiest_Station['TIME'].index)):
    
    if Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] < ('04:00:00'):
        Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('00:00 - 04:00')
    
    elif ('04:00:00') <= Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] < ('08:00:00'):
        Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('04:00 - 08:00')
    
    elif ('08:00:00') <= Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] < ('12:00:00'):
        Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('08:00 - 12:00')
    
    elif ('12:00:00') <= Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] < ('16:00:00'):
        Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('12:00 - 16:00')
    
    elif ('16:00:00') <= Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] < ('20:00:00'):
        Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('16:00 - 20:00')
    
    elif ('20:00:00') <= Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]]:
        Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('20:00 - 00:00')
        
    i = i + 1
    
Most_Busiest_Station
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_6040/983574974.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('00:00 - 04:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_6040/983574974.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('04:00 - 08:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_6040/983574974.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('08:00 - 12:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_6040/983574974.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('12:00 - 16:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_6040/983574974.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('16:00 - 20:00')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_6040/983574974.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Most_Busiest_Station['TIME'][Most_Busiest_Station['TIME'].index[i]] =  ('20:00 - 00:00')
#                 STATION           TURNSTILE        DATE           TIME  \
# 53864    34 ST-PENN STA  N067-R012-00-00-00  04/25/2020  00:00 - 04:00
# 53865    34 ST-PENN STA  N067-R012-00-00-00  04/25/2020  04:00 - 08:00
# 53866    34 ST-PENN STA  N067-R012-00-00-00  04/25/2020  08:00 - 12:00
# 53867    34 ST-PENN STA  N067-R012-00-00-00  04/25/2020  12:00 - 16:00
# 53868    34 ST-PENN STA  N067-R012-00-00-00  04/25/2020  16:00 - 20:00
# ...                 ...                 ...         ...            ...
# 3672475  34 ST-PENN STA  R142-R293-01-06-01  08/28/2020  04:00 - 08:00
# 3672476  34 ST-PENN STA  R142-R293-01-06-01  08/28/2020  08:00 - 12:00
# 3672477  34 ST-PENN STA  R142-R293-01-06-01  08/28/2020  12:00 - 16:00
# 3672478  34 ST-PENN STA  R142-R293-01-06-01  08/28/2020  16:00 - 20:00
# 3672479  34 ST-PENN STA  R142-R293-01-06-01  08/28/2020  20:00 - 00:00
#
#                   TIMESTAMP   ENTRIES     EXITS  WEEKDAYS  NET_ENTRIES  \
# 53864   2020-04-25 00:00:00    198195    594376  Saturday      0.00000
# 53865   2020-04-25 04:00:00    198195    594380  Saturday      1.00000
# 53866   2020-04-25 08:00:00    198196    594384  Saturday      0.00000
# 53867   2020-04-25 12:00:00    198196    594389  Saturday      2.00000
# 53868   2020-04-25 16:00:00    198198    594396  Saturday      1.00000
# ...                     ...       ...       ...       ...          ...
# 3672475 2020-08-28 06:00:00  68045757  18700963    Friday      6.00000
# 3672476 2020-08-28 10:00:00  68045763  18701017    Friday     27.00000
# 3672477 2020-08-28 14:00:00  68045790  18701068    Friday     44.00000
# 3672478 2020-08-28 18:00:00  68045834  18701105    Friday     18.00000
# 3672479 2020-08-28 22:00:00  68045852  18701142    Friday      9.00000
#
#          NET_EXITS  TRAFFIC  WEEKDAYS_INDEX
# 53864      4.00000  4.00000               5
# 53865      4.00000  5.00000               5
# 53866      5.00000  5.00000               5
# 53867      7.00000  9.00000               5
# 53868      1.00000  2.00000               5
# ...            ...      ...             ...
# 3672475   54.00000 60.00000               4
# 3672476   51.00000 78.00000               4
# 3672477   37.00000 81.00000               4
# 3672478   37.00000 55.00000               4
# 3672479   11.00000 20.00000               4
#
# [75160 rows x 12 columns]

# %%
BT_of_MBS = Most_Busiest_Station.groupby(["TIME","WEEKDAYS","WEEKDAYS_INDEX"]).agg({'TRAFFIC':'sum'}).reset_index()[["TIME","WEEKDAYS","TRAFFIC","WEEKDAYS_INDEX"]]
BT_of_MBS
# Out:
#              TIME   WEEKDAYS      TRAFFIC  WEEKDAYS_INDEX
# 0   00:00 - 04:00     Friday  12702.00000               4
# 1   00:00 - 04:00     Monday  12508.00000               0
# 2   00:00 - 04:00   Saturday   9442.00000               5
# 3   00:00 - 04:00     Sunday   8554.00000               6
# 4   00:00 - 04:00   Thursday  13672.00000               3
# 5   00:00 - 04:00    Tuesday  13830.00000               1
# 6   00:00 - 04:00  Wednesday  13252.00000               2
# 7   04:00 - 08:00     Friday 109280.00000               4
# 8   04:00 - 08:00     Monday 107547.00000               0
# 9   04:00 - 08:00   Saturday  54905.00000               5
# 10  04:00 - 08:00     Sunday  40600.00000               6
# 11  04:00 - 08:00   Thursday 112724.00000               3
# 12  04:00 - 08:00    Tuesday 114322.00000               1
# 13  04:00 - 08:00  Wednesday 111390.00000               2
# 14  08:00 - 12:00     Friday 115648.00000               4
# 15  08:00 - 12:00     Monday 113527.00000               0
# 16  08:00 - 12:00   Saturday  77398.00000               5
# 17  08:00 - 12:00     Sunday  64384.00000               6
# 18  08:00 - 12:00   Thursday 116963.00000               3
# 19  08:00 - 12:00    Tuesday 116442.00000               1
# 20  08:00 - 12:00  Wednesday 115268.00000               2
# 21  12:00 - 16:00     Friday 146824.00000               4
# 22  12:00 - 16:00     Monday 141317.00000               0
# 23  12:00 - 16:00   Saturday  99843.00000               5
# 24  12:00 - 16:00     Sunday  87772.00000               6
# 25  12:00 - 16:00   Thursday 144778.00000               3
# 26  12:00 - 16:00    Tuesday 142081.00000               1
# 27  12:00 - 16:00  Wednesday 144333.00000               2
# 28  16:00 - 20:00     Friday 127279.00000               4
# 29  16:00 - 20:00     Monday 122262.00000               0
# 30  16:00 - 20:00   Saturday  91072.00000               5
# 31  16:00 - 20:00     Sunday  87052.00000               6
# 32  16:00 - 20:00   Thursday 127451.00000               3
# 33  16:00 - 20:00    Tuesday 123598.00000               1
# 34  16:00 - 20:00  Wednesday 126353.00000               2
# 35  20:00 - 00:00     Friday  35620.00000               4
# 36  20:00 - 00:00     Monday  57607.00000               0
# 37  20:00 - 00:00   Saturday  54975.00000               5
# 38  20:00 - 00:00     Sunday  50630.00000               6
# 39  20:00 - 00:00   Thursday  59137.00000               3
# 40  20:00 - 00:00    Tuesday  57984.00000               1
# 41  20:00 - 00:00  Wednesday  58602.00000               2

# %%
plt.figure(figsize=(12,8),dpi=200)
revels = BT_of_MBS.pivot("TIME", "WEEKDAYS_INDEX", "TRAFFIC")
revels.columns = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
ax = sns.heatmap(revels, linewidths=0.4, cmap="Oranges")
ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
plt.xlabel(' ')
plt.ylabel(' ')
plt.title("BUSIEST DAYS AND TIMES FOR 34 ST-PENN STATION 2019", family='serif',fontsize = 15,loc='center',color='Red')
plt.show()

# %%
revels = BT_of_MBS.pivot("TIME", "WEEKDAYS_INDEX", "TRAFFIC")

# %%
revels.columns = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']

# %%
ax = sns.heatmap(revels, linewidths=0.4, cmap="Oranges")

# %%
ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
plt.xlabel(' ')
plt.ylabel(' ')

# %%
plt.title("BUSIEST DAYS AND TIMES FOR 34 ST-PENN STATION 2020", family='serif',fontsize = 15,loc='center',color='Red')
plt.show()
